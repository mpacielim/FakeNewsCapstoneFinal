# %% [markdown]
# # Capstone Project 24:1 - Classifying Fake News Final Report

# %% [markdown]
# # Table of Contents
#
# 1. [Part 1: Data Collection and Preprocessing](#section1)
#     - [1A: Data Collection](#section1A)
#     - [1B: Dataset Cleaning](#section1B)
#     - [1C: Shrink Dataset](#section1C)
#     - [1D: Text Preprocessing](#section1D)
# <br><br>
# 2. [Part 2: Modelling with Non-Neural Models](#section2)
#     - [2A: Create X and y Dataframes](#section2A)
#     - [2B: Calculate Baseline](#section2B)
#     - [2C: Cross Validate and Tune Different Models](#section2C)
#     - [2D: Model Review and Selection](#section2D)
# <br><br>
# 3. [Part 3: Modelling with Recurrent Neural Network Model](#section3)
#     - [3A: Motivation](#section3A)
#     - [3B: Additional Preprocessing of X and y Dataframes](#section3B)
#     - [3C: Cross Validate and Tune Model](#section3C)
#     - [3D: Model Review and Comparison](#section3D)
#     - [3E: Deepdive RNN Model Performance and Limitations on a Sample](#section3E)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import nltk
import string
import time

from IPython.display import Markdown, display

from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk import word_tokenize, sent_tokenize, pos_tag
from nltk.corpus import stopwords
from collections import Counter

nltk.download('words')
nltk.download('stopwords')

from gensim.models import KeyedVectors

from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV 
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import mean_squared_error, accuracy_score, recall_score, f1_score , precision_score, classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_recall_curve, auc, roc_curve
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.layers import Embedding, Dense, LSTM, SimpleRNN, Flatten, MaxPooling1D, Conv1D, GlobalAveragePooling1D
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.utils import to_categorical

from lime.lime_text import LimeTextExplainer

from keras import backend as K

import warnings
warnings.filterwarnings("ignore")
sns.set_style("whitegrid")
sns.set_palette("rocket")
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\mpaci\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mpaci\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# <a id="section1"></a>
# # Part 1: Data Collection, Analysis and Preprocessing

# %% [markdown]
# <a id="section1A"></a>
# ## 1A: Data Collection

# %% [markdown]
# The dataset to be used in this analysis is the [Fake News Classification Dataset](https://www.kaggle.com/datasets/saurabhshahane/fake-news-classification) from Kaggle.

# %%
df_original = pd.read_csv('data/WELFake_Dataset.csv')

# %%
df_original.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0  LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1           1                                                NaN
# 2           2  UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 3           3  Bobby Jindal, raised Hindu, uses story of Chri...
# 4           4  SATAN 2: Russia unvelis an image of its terrif...
#
#                                                 text  label
# 0  No comment is expected from Barack Obama Membe...      1
# 1     Did they post their votes for Hillary already?      1
# 2   Now, most of the demonstrators gathered last ...      1
# 3  A dozen politically active pastors came here f...      0
# 4  The RS-28 Sarmat missile, dubbed Satan 2, will...      1

# %% [markdown]
# <a id="section1B"></a>
# ## 1B: Dataset Cleaning

# %% [markdown]
# Before processing the actual contents of the text, we will perform a general clean up on the raw dataset.  This will include:
#
# 1. Remove unnecessary columns
# 2. Relabel column titles
# 3. Remove duplicate rows
# 4. Remove missing data from rows

# %% [markdown]
# First we will create a deep copy of the original dataframe before modifying the data:

# %%
df_clean = df_original.copy()

# %% [markdown]
# ### i) Remove unnecessary columns

# %%
df_clean['Unnamed: 0'].nunique()
# Out:
# 72134

# %% [markdown]
# Kaggle dataset shows this column as the 'serial number', and as the number of unique values is equivalent to the number of entries, we can confidently equate this to just the index number.  This redundant column will be dropped.

# %%
df_clean = df_clean.drop(['Unnamed: 0'], axis=1)

# %% [markdown]
# ### ii) Rename columns

# %% [markdown]
# After reviewing the comments on the Kaggle dataset and performing cross checks, the 'label' column is a binary classifier that determines whether the article is either:
# 1. Fake = 1
# 2. Real = 0
#
# We will rename the label column and capitalize the other two column titles:

# %%
df_clean.columns = ['Title','Text','Fake']
df_clean.head()
# Out:
#                                                Title  \
# 0  LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1                                                NaN
# 2  UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 3  Bobby Jindal, raised Hindu, uses story of Chri...
# 4  SATAN 2: Russia unvelis an image of its terrif...
#
#                                                 Text  Fake
# 0  No comment is expected from Barack Obama Membe...     1
# 1     Did they post their votes for Hillary already?     1
# 2   Now, most of the demonstrators gathered last ...     1
# 3  A dozen politically active pastors came here f...     0
# 4  The RS-28 Sarmat missile, dubbed Satan 2, will...     1

# %% [markdown]
# ### iii) Remove duplicates

# %% [markdown]
# We don't want to train or test the model on duplicated information, as this will cause bias in the results weighted towards those duplicates.
#
# Instead of checking for duplicates of text AND title, we will check for duplicate titles and text separately, since there may be duplicate cases where the text or title is different, but the text or title is repeated in another entry.

# %%
#Check how many duplicated titles there are
duplicate_titles = df_clean.duplicated(subset = ['Title','Fake'])
print('There are',duplicate_titles.sum(), 'entries with duplicated titles')
# Out:
# There are 9782 entries with duplicated titles

# %%
#Check how many duplicated bodies of text there are 
duplicate_text = df_clean.duplicated(subset = ['Text', 'Fake'])
duplicate_text.sum()
print('There are', duplicate_text.sum(), 'entries with duplicated text')
# Out:
# There are 9414 entries with duplicated text

# %%
#Remove duplicates
df_clean = df_clean.drop_duplicates(subset = ['Title','Fake'])
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62352 entries, 0 to 72132
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Title   62351 non-null  object
#  1   Text    62313 non-null  object
#  2   Fake    62352 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.9+ MB

# %%
#Remove duplicates
df_clean = df_clean.drop_duplicates(subset = ['Text','Fake'])
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61400 entries, 0 to 72132
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Title   61399 non-null  object
#  1   Text    61399 non-null  object
#  2   Fake    61400 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.9+ MB

# %%
print(f"Removing duplicates dropped {len(df_original) - len(df_clean):,} values from our original dataset, or {(len(df_original) - len(df_clean)) / len(df_original) * 100:.0f}% of the original dataset.")
# Out:
# Removing duplicates dropped 10,734 values from our original dataset, or 15% of the original dataset.

# %% [markdown]
# ### iv) Remove missing data

# %% [markdown]
# We can see from the summary above that there is atleast 1 row of missing data in title and text. We will remove it below.

# %%
df_clean.dropna(inplace = True)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61398 entries, 0 to 72132
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Title   61398 non-null  object
#  1   Text    61398 non-null  object
#  2   Fake    61398 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.9+ MB

# %% [markdown]
# Now we have a clean dataset to manipulate and perform text pre-processing on.

# %% [markdown]
# ### v) Review cleaned data and remove outliers

# %% [markdown]
# Before we do the text processing, we will take a broad look at the characteristics of the data to get more familiarized with it.

# %% [markdown]
# In order to get more familiarized with the cleaned data and to check if we need to do any further data cleaning, we will check and visualize the distribution of:
# 1. Classifications
# 2. Word Counts
# 3. Character Counts (includes letters, punctuation and spaces)
# 4. Unique Words

# %%
#Calculate word counts for the Text and Title columns separately
df_clean['Text Word Count'] = df_clean['Text'].apply(lambda text: len(str(text).split()))
df_clean['Title Word Count'] = df_clean['Title'].apply(lambda text: len(str(text).split()))

#Calculate respective character counts (including spaces and punctuation)
df_clean['Text Character Count'] = df_clean['Text'].apply(lambda text: len(str(text)))
df_clean['Title Character Count'] = df_clean['Title'].apply(lambda text: len(str(text)))

# %%
df_clean.head()
# Out:
#                                                Title  \
# 0  LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 2  UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 3  Bobby Jindal, raised Hindu, uses story of Chri...
# 4  SATAN 2: Russia unvelis an image of its terrif...
# 5  About Time! Christian Group Sues Amazon and SP...
#
#                                                 Text  Fake  Text Word Count  \
# 0  No comment is expected from Barack Obama Membe...     1              871
# 2   Now, most of the demonstrators gathered last ...     1               34
# 3  A dozen politically active pastors came here f...     0             1321
# 4  The RS-28 Sarmat missile, dubbed Satan 2, will...     1              329
# 5  All we can say on this one is it s about time ...     1              244
#
#    Title Word Count  Text Character Count  Title Character Count
# 0                18                  5049                    130
# 2                18                   216                    137
# 3                16                  8010                    105
# 4                16                  1916                     95
# 5                13                  1530                     78

# %%
plt.figure(figsize=(4, 4))

ax = sns.countplot(x='Fake', data=df_clean, palette='coolwarm')

ax.set_title('Dataset Class Distribution', fontsize=12)
ax.set_xlabel('Real or Fake News?', fontsize=10)
ax.set_ylabel('Count', fontsize=10)
ax.tick_params(axis='both', which='major', labelsize=10)

ax.set_xticklabels(['0: Real', '1: Fake'])

# Calculate the total number of entries
total = len(df_clean)

# Add % annotations
for p in ax.patches:
    height = p.get_height()
    percentage = '{:.1f}%'.format(100 * height/total)
    ax.text(p.get_x() + p.get_width() / 2., height + 3, percentage, ha='center', fontsize=10)
    
plt.show()

# %% [markdown]
# From here we can see that we have a somewhat balanced dataset, with a slight bias towards real news (55% of samples) vs fake news (45% of samples).  As a result, we will need to consider more than just accuracy as an evaluation metric in order to asses model performance.

# %%
df_clean[['Text Word Count',
 'Title Word Count',
 'Text Character Count',
 'Title Character Count']].describe(percentiles=[0.01, 0.25, 0.75, 0.9]).applymap(lambda x: "{:,.0f}".format(x))
# Out:
#       Text Word Count Title Word Count Text Character Count  \
# count          61,398           61,398               61,398
# mean              552               12                3,334
# std               611                4                3,637
# min                 0                1                    1
# 1%                 22                5                  137
# 25%               249                9                1,512
# 50%               407               11                2,490
# 75%               680               14                4,132
# 90%             1,107               17                6,674
# max            24,234               72              142,961
#
#       Title Character Count
# count                61,398
# mean                     75
# std                      23
# min                       1
# 1%                       30
# 25%                      61
# 50%                      72
# 75%                      87
# 90%                     100
# max                     456

# %% [markdown]
# From this summary we can see that:
# 1. Titles on average are 12 words long, and 75 characters
# 2. Bodies of text are an average of 552 words long and 3,300 characters
#
# There are some obvious outliers but overall the  in each, including some text that is 0 characters and some 1 word titles.
#
# To capture a wider range of nonsensical outliers, we will remove any samples that are smaller than the first percentile (<20 words for the article text, and <5 words for title).

# %%
#Calculate original number of entries
len_original = len(df_clean)

#Create boolean filter to filter for the opposite of our outlier conditions
filter = (df_clean['Text Word Count'] >= 20) & (df_clean['Title Word Count'] >= 5)

#Remove filtered data
df_clean = df_clean[filter]

#Calculate new length
len_new = len(df_clean)

#Change in length
len_change = len_new - len_original
len_change_percent = len_change / len_original *100

# %%
#Re-review sample to confirm outliers have been removed
df_clean[['Text Word Count',
 'Title Word Count',
 'Text Character Count',
 'Title Character Count']].describe(percentiles=[0.01, 0.25, 0.75, 0.9]).applymap(lambda x: "{:,.0f}".format(x))
# Out:
#       Text Word Count Title Word Count Text Character Count  \
# count          60,410           60,410               60,410
# mean              554               12                3,346
# std               608                4                3,614
# min                20                5                   95
# 1%                 33                6                  200
# 25%               255                9                1,549
# 50%               409               11                2,502
# 75%               681               14                4,135
# 90%             1,105               17                6,658
# max            24,234               58              142,961
#
#       Title Character Count
# count                60,410
# mean                     76
# std                      22
# min                      19
# 1%                       35
# 25%                      62
# 50%                      72
# 75%                      87
# 90%                     100
# max                     396

# %%
print(f"Removing outliers dropped {-len_change:,} values from our original dataset, or {-len_change_percent:.0f}% of the original dataset.")
# Out:
# Removing outliers dropped 988 values from our original dataset, or 2% of the original dataset.

# %% [markdown]
# Below, we visualize the remain data to better see how the character and text count is distributed.

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 12), gridspec_kw={'height_ratios': [1, 1.1]})
fig.suptitle('Text and Title Character and Word Count Histograms', fontsize=16)

title_color = "skyblue"
text_color = "salmon"
title_size = 14

# Plot 1: Title Character Count
sns.histplot(df_clean['Title Character Count'], bins=100, ax=axs[0, 0], color=title_color)
axs[0, 0].set_title('Title Character Count', fontsize=title_size)
axs[0, 0].set_xlim(0, 200)
axs[0, 0].set_xlabel('# of Characters', fontsize=10)

# Plot 2: Text Character Count
sns.histplot(df_clean['Text Character Count'], bins=1000, ax=axs[0, 1], color=text_color)
axs[0, 1].set_title('Text Character Count', fontsize=title_size)
axs[0, 1].set_xlim(0, 15000)
axs[0, 1].set_xlabel('# of Characters', fontsize=10)

# Plot 3: Title Word Count
sns.histplot(df_clean['Title Word Count'], bins=30, ax=axs[1, 0], color=title_color)
axs[1, 0].set_title('Title Word Count', fontsize=title_size)
axs[1, 0].set_xlim(0, 75)
axs[1, 0].set_xlabel('# of Words', fontsize=10)

# Plot 4: Text Word Count
sns.histplot(df_clean['Text Word Count'], bins=1000, ax=axs[1, 1], color=text_color)
axs[1, 1].set_title('Text Word Count', fontsize=title_size)
axs[1, 1].set_xlim(0, 3000)
axs[1, 1].set_xlabel('# of Words', fontsize=10)

# Show the plot
plt.show()

# %% [markdown]
# From the description summary above and the following histograms, we can see that:
# 1. The text count is skewed to the to the left and has two peaks at around 250 words and 100 words per article
# 2. The title count is fairly normally distributed if we remove the upper outlies around 75 words per title.
#
# This is interesting to see and might indicate that we will need to standardize or pad out the vectorized columns, depending on how many more words are removed, however for the moment we will not transform the distributions as we want to try and capture as many different types of articles as possible.  If the model is performing very poorly, we might consider this, but for now we will keep the data as is.

# %% [markdown]
# <a id="section1C"></a>
# ## 1C: Shrink Dataset

# %% [markdown]
# Due to the heavy computational resources required to process text data, I will shrink the dataset to a size that will be faster to process.

# %%
#First create a copy of the dataframe
df_clean_copy = df_clean.copy()

# %%
sample_size = 1000

# %%
df = df_clean_copy.sample(sample_size, random_state = 42).reset_index(drop=True)

# %% [markdown]
# Perform a quick check to see how the data is distributed in this smaller sample:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  1000 non-null   object
#  1   Text                   1000 non-null   object
#  2   Fake                   1000 non-null   int64
#  3   Text Word Count        1000 non-null   int64
#  4   Title Word Count       1000 non-null   int64
#  5   Text Character Count   1000 non-null   int64
#  6   Title Character Count  1000 non-null   int64
# dtypes: int64(5), object(2)
# memory usage: 54.8+ KB

# %%
#Re-review sample to confirm outliers have been removed
df[['Text Word Count',
 'Title Word Count',
 'Text Character Count',
 'Title Character Count']].describe(percentiles=[0.01, 0.25, 0.75, 0.9]).applymap(lambda x: "{:,.0f}".format(x))
# Out:
#       Text Word Count Title Word Count Text Character Count  \
# count           1,000            1,000                1,000
# mean              539               12                3,258
# std               538                4                3,221
# min                20                5                  117
# 1%                 42                6                  253
# 25%               254                9                1,547
# 50%               395               12                2,402
# 75%               679               14                4,102
# 90%             1,073               17                6,530
# max             6,628               38               39,735
#
#       Title Character Count
# count                 1,000
# mean                     76
# std                      23
# min                      29
# 1%                       37
# 25%                      62
# 50%                      72
# 75%                      88
# 90%                     100
# max                     255

# %%
plt.figure(figsize=(4, 4))

ax = sns.countplot(x='Fake', data=df, palette='coolwarm')

ax.set_title('Shrunk Dataset Class Distribution', fontsize=12)
ax.set_xlabel('Real or Fake News?', fontsize=10)
ax.set_ylabel('Count', fontsize=10)
ax.tick_params(axis='both', which='major', labelsize=10)

ax.set_xticklabels(['0: Real', '1: Fake'])

# Calculate the total number of entries
total = len(df)

# Add % annotations
for p in ax.patches:
    height = p.get_height()
    percentage = '{:.1f}%'.format(100 * height/total)
    ax.text(p.get_x() + p.get_width() / 2., height + 3, percentage, ha='center', fontsize=10)
    
plt.show()

# %% [markdown]
# The distribution of our reduced sample size is similar to the original dataset (56/44% split), with slightly more skew towards Real news.

# %% [markdown]
# <a id="section1D"></a>
# ## 1D: Text Preprocessing

# %% [markdown]
# Before any further processing, we will remove the word and character count summaries from our dataframe:

# %%
df.drop(['Text Word Count',
 'Title Word Count',
 'Text Character Count',
 'Title Character Count'], axis = 1, inplace=True)

# %% [markdown]
# In order to review and process the model using machine learning methods from python, the text data needs to be converted to numerical data.
#
# This requires the following steps:
# 1. Tokenize the text
# 2. Remove common stop words
# 3. Remove punctuation
# 4. Lemmatize words
# - We are choosing lemmatize over stemming due to the nature of wanting to keep as much linguistic context of the text in the model as possible.  We want to be able to identify true or false news.  False news could have the same general content as true news, but subtle differences in word usage, which we hope to capture via lemmatization.
#
# Note that in future iterations of the model, if we need to improve performance it might be worth replacing stop words and punctuation, as these could prove to be important in distinguishing between fake and real publications.  This would be similar to choosing lemmatization over stemming, however for now we will keep them removed to help speed up processing, and assess model performance before adding them back in.

# %%
def tokenize(text):
    # Tokenize only if the input is a string
    return word_tokenize(text) if isinstance(text, str) else []

def clean_tokens(tokens, stop_words, punc):
    # Combine the processing steps into a single function
    tokens = [word.lower() for word in tokens if word.lower() not in stop_words and word not in punc]
    return tokens

# Initializing stop words, stemmer, lemmatizer, and punctuation list
stop_words = set(stopwords.words('english'))
lemma = WordNetLemmatizer()
extended_punc = list(string.punctuation) + ['“', '”', '’', '‘', '—', '``', "''",'–']

# Function to apply all text processing steps
def process_text_column(column):
    cleaned_tokens = column.apply(lambda x: clean_tokens(tokenize(x), stop_words, extended_punc))
    lemmatized = cleaned_tokens.apply(lambda tokens: [lemma.lemmatize(word) for word in tokens])
    return cleaned_tokens, lemmatized

# Apply text processing to both Title and Text columns
df['Cleaned Tokens Title'], df['Lemmatized Title'] = process_text_column(df['Title'])
df['Cleaned Tokens Text'], df['Lemmatized Text'] = process_text_column(df['Text'])

# %%
df.head()
# Out:
#                                                Title  \
# 0  Lawyers Mobilize at Nation’s Airports After Tr...
# 1  U.S. education secretary calls Obama transgend...
# 2  Millions to lose health insurance under Republ...
# 3          Trump RNC manager: 'Winning isn't enough'
# 4  Obama says protectionism no answer to inequali...
#
#                                                 Text  Fake  \
# 0  Even before President Trump issued an order on...     0
# 1  WASHINGTON (Reuters) - U.S. Education Secretar...     0
# 2  WASHINGTON (Reuters) - Millions of Americans w...     0
# 3  "This is an example of Donald Trump managing, ...     0
# 4  (Reuters) - America must work with all nations...     0
#
#                                 Cleaned Tokens Title  \
# 0  [lawyers, mobilize, nation, airports, trump, o...
# 1  [u.s., education, secretary, calls, obama, tra...
# 2  [millions, lose, health, insurance, republican...
# 3       [trump, rnc, manager, 'winning, n't, enough]
# 4  [obama, says, protectionism, answer, inequalit...
#
#                                     Lemmatized Title  \
# 0  [lawyer, mobilize, nation, airport, trump, ord...
# 1  [u.s., education, secretary, call, obama, tran...
# 2  [million, lose, health, insurance, republican,...
# 3       [trump, rnc, manager, 'winning, n't, enough]
# 4  [obama, say, protectionism, answer, inequality...
#
#                                  Cleaned Tokens Text  \
# 0  [even, president, trump, issued, order, friday...
# 1  [washington, reuters, u.s., education, secreta...
# 2  [washington, reuters, millions, americans, wou...
# 3  [example, donald, trump, managing, type, leade...
# 4  [reuters, america, must, work, nations, build,...
#
#                                      Lemmatized Text
# 0  [even, president, trump, issued, order, friday...
# 1  [washington, reuters, u.s., education, secreta...
# 2  [washington, reuters, million, american, would...
# 3  [example, donald, trump, managing, type, leade...
# 4  [reuters, america, must, work, nation, build, ...

# %% [markdown]
# #### Visualise top words in each category

# %%
def plot_top_words(df, column, title, ax):
    # Sum all words in the column
    words = df[column].sum()
    total_words = len(words)
    word_counts = Counter(words)

    # Calculate the percentage of each word relative to the total word count
    top_words = {word: (count / total_words) * 100 for word, count in word_counts.most_common(10)}

    # Convert to DataFrame for plotting
    top_words_df = pd.DataFrame(list(top_words.items()), columns=['Word', '% of Words'])

    # Plot
    sns.barplot(y='Word', x='% of Words', data=top_words_df, ax=ax)
    ax.set_title(title)

# Create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2, figsize=(15, 12))

# Filter the DataFrame for Fake = 1 and Fake = 0 (Real)
df_fake_1 = df[df['Fake'] == 1]
df_fake_0 = df[df['Fake'] == 0]

# Call the function for each column and condition
plot_top_words(df_fake_1, 'Lemmatized Title', 'Top 10 Lemmatized Words in Fake News Titles', axs[0, 0])
plot_top_words(df_fake_1, 'Lemmatized Text', 'Top 10 Lemmatized Words in Fake News Text', axs[1, 0])
plot_top_words(df_fake_0, 'Lemmatized Title', 'Top 10 Lemmatized Words in Real News Titles', axs[0, 1])
plot_top_words(df_fake_0, 'Lemmatized Text', 'Top 10 Lemmatized Words in Real News Text', axs[1, 1])

plt.tight_layout()
plt.show()

# %% [markdown]
# Above we see some interesting summaries of what the main words are in each type of news article, and can discern the dataset appears to be centered around US politics, with a similar spread of topics between both fake and real news (Trump, president, state, people showing up in both categories).

# %% [markdown]
# <a id="section2"></a>
# # Part 2: Modelling with Non-Neural Models

# %% [markdown]
# In the interest of time, for the X matrix, we will only use the tokenized title in the model and assess how the model performs.
#
# If time permits, we will change the analysis to tokenized text, or a combination of title and text.

# %% [markdown]
# <a id="section2A"></a>
# ## 2A:  Create X and y Dataframes

# %% [markdown]
# In order to perform modelling, we need to convert the tokenized words into numerical vectors.

# %%
#First join tokenized words back into a string, separating with spaces, as is required for tokenizing using Scikit Learn

X = [' '.join(token) for token in df['Lemmatized Title']]
y = df['Fake']

# %% [markdown]
# ### Split X and y into test and train validation sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 22)

# %% [markdown]
# <a id="section2B"></a>
# ## 2B: Calculate Baseline

# %% [markdown]
# As a first step to assessing our future models performance, we will create a baseline that our classifier should aim to beat.
#
# Because this is a binary classification model, we will look at the accuracy of the model predicting the majority class for all data points as the baseline.

# %%
test_baseline = y_test.value_counts(normalize = True)
test_baseline
# Out:
# Fake
# 0    0.54
# 1    0.46
# Name: proportion, dtype: float64

# %%
train_baseline = y_train.value_counts(normalize = True)
train_baseline
# Out:
# Fake
# 0    0.590667
# 1    0.409333
# Name: proportion, dtype: float64

# %%
display(Markdown(f'In our case, where 0 = real news and 1 = fake news, we can define our baseline performance as {test_baseline[0]*100:.0f}% for the test datasets. \n\nThis means that if the model classified every single datapoint as the majority class ("Real"), then it would have ~ {test_baseline[0]*100:.0f}% accuracy.\n\nOur aim is to improve model performance beyond this.'))
# Out:
# In our case, where 0 = real news and 1 = fake news, we can define our baseline performance as 54% for the test datasets.
#
# This means that if the model classified every single datapoint as the majority class ("Real"), then it would have ~ 54% accuracy.
#
# Our aim is to improve model performance beyond this.

# %% [markdown]
# <a id="section2C"></a>
# ## 2C: Cross Validate and Tune Different Models

# %% [markdown]
# ### Methodology

# %% [markdown]
# Four machine learning algorithms that are commonly used for classifying binary data will be trained and tested on our news dataset.  These are our 'models':
# - i) Naive Bayes
# - ii) Decision Tree
# - iii) Logistic Regression
# - iv) Support Vector Classification (SVC)
#
# For each model, we will:
# 1. Convert the text data to numerical data that can be processed by the algorithm.
#     - We will uses TF-IDF to vectorize the tokenized, lemmatized data from our data cleaning step.
#     - This converts words to numbers based on both their frequency and rarity within a body of text.
# 2. Train and test the model over several iterations with different hyperparameters, with the intent of picking the best performing hyperparameter for that model type.
#     - Runs a GridSearch Cross Validation (CV) using different parameters for each model.
#     - We will leave the default cross validation at k-fold of 5 folds.
#     - This means that the model will divide the training dataset into 5 equally sized groups, and perform five iterations of training on 4 out of the 5 sets, and using the remaining group as the test set in each case.
#     - In this way, the model is picking the best parameters for itself based on its average performance with these 5 iterations.
#     - This ensures that the entire dataset is used for training and testing the model, which reduces the likelihood of the model being too specific to the data it was trained on (also known as overfitting), and thus being able to generalize to and perform better on new unseen data.
# 3. Retrain the model with the best hyperparameter as identified by the GridSearchCV method.
# 4. Calculate evaluation metrics for the best model for that specific type of model
# 5. Collate the metrics into a dataframe to compare with the best performing model for all the other model types.
#
# Finally, to pick the best model:
# - We will choose based on the model that has achieved the best performance metrics.  In this case, we will pick the one with the highest F1 score.

# %% [markdown]
# ### Rationale for Evaluation Metric Choice

# %% [markdown]
# Because our dataset is slightly unbalanced (the majority class represents >50% of the data), we want to consider recall, precision and f1 score in our model evaluation.
#
# To provide more context to our choice of evaluation metrics for our unbalanced dataset, the definitions are provided below.
#
# For our dataset:
# - The Positive Class (1) is Fake news
# - The Negative Class (0) is Real news
#
# In this context, there is a high societal cost to both:
# - **False Positives** - incorrectly identifying Real news as Fake (undermines legitimate news sources and spreads distrust).
# - **False Negatives** - incorrectly identifying Fake news as Real (further spreads misinformation and unnecessary hysteria).

# %% [markdown]
# $$
# \text{Recall} = \frac{\text{True Positives}}{\text{True Positives} + \text{False Negatives}}
# $$

# %% [markdown]
# Recall answers the question "Of all actual Fake news in the sample, how many did the model correctly identify?"
#
# If there is a high False Negative rate (Fake news incorrectly labelled as Real), recall will be low.
#
# Thus we are looking for a **high recall** rate.

# %% [markdown]
# $$
# \text{Precision} = \frac{\text{True Positives}}{\text{True Positives} + \text{False Positives}}
# $$

# %% [markdown]
# Precision answers the question "Of all the samples that were labelled as Fake news, how many were actually Fake?"
#
# If there is a high False Positive rate (Real news incorrectly labelled as Fake), precision will be low.
#
# Thus we are looking for a **high precision** rate.

# %% [markdown]
# $$
# \text{F1 Score} = 2 \times \frac{\text{Precision} \times \text{Recall}}{\text{Precision} + \text{Recall}}
# $$

# %% [markdown]
# The F1 score is the harmonic mean of precision and recall, and can only be high if there is both high precision and high recall - which is what we want.
#
# There is usually a trade off between precision and recall. Thus when the cost of False Negative and False Positives is high, which is true for our problem, we want to **maximize F1**.

# %% [markdown]
# A secondary metric we want to review to ensure that the model has a higher tendency to maximize the F1 score across different thresholds is the **Precision-Recall Area Under Curve (PR-AUC)**.
#
# - The **higher** the PR-AUC is, the more likely the model is to be able to maintain high recall and precision across a wide range of thresholds, which is important for striking a balance between classifying both classes accurately.
# - The default threshold we use in our modelling is 0.5, meaning if the likelihood that the sample belongs to the Fake class is >50%, the model will assign it as Fake.
# - If we wanted to do further analysis or model tuning to change the threshold, then a higher PR-AUC score means we will be more likely to maintain a high F1 with a different threshold.
# - The curve also visualizes the what the recall and precision rates are at each threshold, which can be used to pick a threshold that provides a more desirable recall and precision rate.

# %% [markdown]
# All of our metrics have a range between 0 and 1.
#
# In our case, we consider the **best performing model** to be the one that has:
# - F1 score as close as possible to 1, as this minimizes the risk of False Positives and False Negatives.

# %% [markdown]
# To assist with our model comparison we will assign a dataframe to collect results of each model.

# %%
results_df = pd.DataFrame(columns = ['Model','Train Duration', 'Test Accuracy', 'Test Recall', 'Test Precision', 'Test F1', 'Test PR AUC'])
results_df
# Out:
# Empty DataFrame
# Columns: [Model, Train Duration, Test Accuracy, Test Recall, Test Precision, Test F1, Test PR AUC]
# Index: []

# %% [markdown]
# ### Model Training
#
# Per the methodology above, we train the four models discussed and collate their results:

# %% [markdown]
# ### i) Naive Bayes

# %%
#Create a Naive Bayes model with  TF-IDF Vectorizer and Multinomial NaiveBayes
nb_pipe = Pipeline([('tfidf', TfidfVectorizer()),
                       ('nb', MultinomialNB())])

#Define parameters for Grid Search
nb_params = {'nb__alpha' : [0,0.0001,0.001,0.01,0.1,1]}

#Define Grid
nb_grid = GridSearchCV(estimator = nb_pipe,
                       param_grid = nb_params,
                       scoring = 'f1')

#Fit Model
nb_start_time = time.time()
nb_grid.fit(X_train, y_train)
nb_duration = time.time() - nb_start_time

#Select best estimator to make predictions
nb_best = nb_grid.best_estimator_
y_pred = nb_best.predict(X_test)

#Score best estimator
nb_accuracy = accuracy_score(y_test, y_pred)
nb_recall = recall_score(y_test, y_pred)
nb_precision = precision_score(y_test, y_pred)
nb_f1 = f1_score(y_test, y_pred)

#Display Best Parameter
nb_params = nb_grid.best_params_
nb_params
# Out:
# {'nb__alpha': 0.1}

# %%
# Predict the probabilities
y_scores = nb_best.predict_proba(X_test)[:, 1]

# Calculate precision and recall for various thresholds
precision, recall, thresholds = precision_recall_curve(y_test, y_scores)

# Calculate PR AUC
nb_pr_auc = auc(recall, precision)

# Plot the PR curve
plt.figure()
plt.plot(recall, precision, label='PR Curve (AUC = %0.2f)' % nb_pr_auc)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Naive Bayes Precision-Recall Area Under Curve (PR-AUC)')
plt.legend(loc="lower left")
plt.show()

# %%
nb_report = {
    'Model': 'Naive Bayes',
    'Train Duration': nb_duration,
    'Test Accuracy': nb_accuracy,
    'Test Recall': nb_recall,
    'Test Precision': nb_precision,
    'Test F1': nb_f1,
    'Test PR AUC': nb_pr_auc}


#results_df = results_df.append(nb_report, ignore_index=True).round(3)
nb_report = pd.DataFrame([nb_report])
results_df = pd.concat([results_df, nb_report], ignore_index=True).round(3)
results_df
# Out:
#          Model  Train Duration  Test Accuracy  Test Recall  Test Precision  \
# 0  Naive Bayes           0.339          0.744        0.583           0.807
#
#    Test F1  Test PR AUC
# 0    0.677        0.826

# %% [markdown]
# ### ii) Decision Tree

# %%
#Create a Decision Tree model with  TF-IDF Vectorizer and DecisionTreeClassifier
dt_pipe = Pipeline([('tfidf', TfidfVectorizer()),
                    ('tree', DecisionTreeClassifier())])

#Define parameters for Grid Search
dt_params = {'tree__min_impurity_decrease': [0.01, 0.02, 0.03, 0.05],
             'tree__criterion': ['gini','entropy'],
             'tree__max_depth' : [1, 2, 3, 4],
             'tree__min_samples_split' : [1, 2, 3, 4]}
                    
                    
#Define Grid
dt_grid = GridSearchCV(estimator = dt_pipe,
                       param_grid = dt_params,
                       scoring = 'f1')

#Fit Model
dt_start_time = time.time()
dt_grid.fit(X_train, y_train)
dt_duration = time.time() - dt_start_time

#Select best estimator to make predictions
dt_best = dt_grid.best_estimator_
y_pred = dt_best.predict(X_test)

#Score best estimator
dt_accuracy = accuracy_score(y_test, y_pred)
dt_recall = recall_score(y_test, y_pred)
dt_precision = precision_score(y_test, y_pred)
dt_f1 = f1_score(y_test, y_pred)

#Display Best Parameter
dt_params = dt_grid.best_params_
dt_params
# Out:
# {'tree__criterion': 'gini',
#  'tree__max_depth': 4,
#  'tree__min_impurity_decrease': 0.01,
#  'tree__min_samples_split': 2}

# %%
# Predict the probabilities
y_scores = dt_best.predict_proba(X_test)[:, 1]

# Calculate precision and recall for various thresholds
precision, recall, thresholds = precision_recall_curve(y_test, y_scores)

# Calculate PR AUC
dt_pr_auc = auc(recall, precision)

# Plot the PR curve
plt.figure()
plt.plot(recall, precision, label='PR Curve (AUC = %0.2f)' % dt_pr_auc)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Decision Tree Precision-Recall Area Under Curve (PR-AUC)')
plt.legend(loc="lower left")
plt.show()

# %%
dt_report = {
    'Model': 'Decision Tree',
    'Train Duration': dt_duration,
    'Test Accuracy': dt_accuracy,
    'Test Recall': dt_recall,
    'Test Precision': dt_precision,
    'Test F1': dt_f1,
    'Test PR AUC': dt_pr_auc}

dt_report = pd.DataFrame([dt_report])
results_df = pd.concat([results_df, dt_report], ignore_index=True).round(3)
results_df
# Out:
#            Model  Train Duration  Test Accuracy  Test Recall  Test Precision  \
# 0    Naive Bayes           0.339          0.744        0.583           0.807
# 1  Decision Tree           9.099          0.684        0.330           0.950
#
#    Test F1  Test PR AUC
# 0    0.677        0.826
# 1    0.490        0.817

# %% [markdown]
# ### iii) Logistic Regression

# %%
#Create a Logistic Regression model with  TF-IDF Vectorizer and a Logistic Regression object
lr_pipe = Pipeline([('tfidf', TfidfVectorizer()),
                    ('lr', LogisticRegression())])

#Define parameters for Grid Search
lr_params = {'lr__fit_intercept': [True,False],
             'lr__class_weight': [None, 'balanced'],
             'lr__penalty': ['none','l1','l2']}
                    
                    
#Define Grid
lr_grid = GridSearchCV(estimator = lr_pipe,
                       param_grid = lr_params,
                       scoring = 'f1')

#Fit Model
lr_start_time = time.time()
lr_grid.fit(X_train, y_train)
lr_duration = time.time() - lr_start_time

#Select best estimator to make predictions
lr_best = lr_grid.best_estimator_
y_pred = lr_best.predict(X_test)

#Score best estimator
lr_accuracy = accuracy_score(y_test, y_pred)
lr_recall = recall_score(y_test, y_pred)
lr_precision = precision_score(y_test, y_pred)
lr_f1 = f1_score(y_test, y_pred)

#Display Best Parameter
lr_params = lr_grid.best_params_
lr_params
# Out:
# {'lr__class_weight': 'balanced',
#  'lr__fit_intercept': False,
#  'lr__penalty': 'l2'}

# %%
# Predict the probabilities
y_scores = lr_best.predict_proba(X_test)[:, 1]

# Calculate precision and recall for various thresholds
precision, recall, thresholds = precision_recall_curve(y_test, y_scores)

# Calculate PR AUC
lr_pr_auc = auc(recall, precision)

# Plot the PR curve
plt.figure()
plt.plot(recall, precision, label='PR Curve (AUC = %0.2f)' % lr_pr_auc)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Logistic Regression Precision-Recall Area Under Curve (PR-AUC)')
plt.legend(loc="lower left")
plt.show()

# %%
lr_report = {
    'Model': 'Logistic Regression',
    'Train Duration': lr_duration,
    'Test Accuracy': lr_accuracy,
    'Test Recall': lr_recall,
    'Test Precision': lr_precision,
    'Test F1': lr_f1,
    'Test PR AUC': lr_pr_auc}

lr_report = pd.DataFrame([lr_report])
results_df = pd.concat([results_df, lr_report], ignore_index=True).round(3)
results_df
# Out:
#                  Model  Train Duration  Test Accuracy  Test Recall  \
# 0          Naive Bayes           0.339          0.744        0.583
# 1        Decision Tree           9.099          0.684        0.330
# 2  Logistic Regression           0.887          0.796        0.765
#
#    Test Precision  Test F1  Test PR AUC
# 0           0.807    0.677        0.826
# 1           0.950    0.490        0.817
# 2           0.786    0.775        0.865

# %% [markdown]
# ### iv) SVC

# %%
#Create a Support Vector Classification model with  TF-IDF Vectorizer and SVC object that records probabilities
svc_pipe = Pipeline([('tfidf', TfidfVectorizer()),
                    ('svc', SVC(probability=True))])

#Define parameters for Grid Search
#Kernel and Gamma are hashed out due to time processing constraints.  These can be uncommented in the future for furhter analysis.
svc_params = {#'svc__kernel': ['rbf', 'poly', 'linear', 'sigmoid'],
              #'svc__gamma': [0.1, 1.0, 10.0, 100.0]
              'svc__C': [0.1, 1, 100]
             }

                    
#Define Grid
svc_grid = GridSearchCV(estimator = svc_pipe,
                        param_grid = svc_params,
                        scoring = 'f1')

#Fit Model
svc_start_time = time.time()
svc_grid.fit(X_train, y_train)
svc_duration = time.time() - svc_start_time

#Select best estimator to make predictions
svc_best = svc_grid.best_estimator_
y_pred = svc_best.predict(X_test)

#Score best estimator
svc_accuracy = accuracy_score(y_test, y_pred)
svc_recall = recall_score(y_test, y_pred)
svc_precision = precision_score(y_test, y_pred)
svc_f1 = f1_score(y_test, y_pred)

#Display Best Parameter
svc_params = svc_grid.best_params_
svc_params
# Out:
# {'svc__C': 100}

# %%
# Predict the probabilities
y_scores = svc_best.predict_proba(X_test)[:, 1]

# Calculate precision and recall for various thresholds
precision, recall, thresholds = precision_recall_curve(y_test, y_scores)

# Calculate PR AUC
svc_pr_auc = auc(recall, precision)

# Plot the PR curve
plt.figure()
plt.plot(recall, precision, label='PR Curve (AUC = %0.2f)' % svc_pr_auc)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('SVC Precision-Recall Area Under Curve (PR-AUC)')
plt.legend(loc="lower left")
plt.show()

# %%
svc_report = {
    'Model': 'SVC',
    'Train Duration': svc_duration,
    'Test Accuracy': svc_accuracy,
    'Test Recall': svc_recall,
    'Test Precision': svc_precision,
    'Test F1': svc_f1,
    'Test PR AUC': svc_pr_auc}

svc_report = pd.DataFrame([svc_report])
results_df = pd.concat([results_df, svc_report], ignore_index=True).round(3)
results_df
# Out:
#                  Model  Train Duration  Test Accuracy  Test Recall  \
# 0          Naive Bayes           0.339          0.744        0.583
# 1        Decision Tree           9.099          0.684        0.330
# 2  Logistic Regression           0.887          0.796        0.765
# 3                  SVC           2.132          0.784        0.635
#
#    Test Precision  Test F1  Test PR AUC
# 0           0.807    0.677        0.826
# 1           0.950    0.490        0.817
# 2           0.786    0.775        0.865
# 3           0.859    0.730        0.867

# %% [markdown]
# <a id="section2D"></a>
# ### 2D: Model Review and Selection

# %% [markdown]
# After running our models, we can see that the best performing model based on the highest F1 score was the **Logistic Regression** model, tuned to its best performing hyperparameters of:
# - Intercept set to 0
# - L2 regularization
#     - This is a technique used to prevent overfitting in the model, by using a term to penalize excessively complex parameters in the model.
# - Balanced class weight
#     - This weights each of the classes to reduce bias towards the more prevalent class.
#
# This resulted in a model with an **F1 score of 0.775**, which we can interpret specifically in terms of number of False Negatives and False Positives using the below confusion matrix.
# - The matrix below shows that out of the 250 test samples, there were:
#     - 24 False Positives (Real news incorrectly identified as Fake)
#     - 27 False Negatives (Fake news incorrectly identified as Real)
#
#
# This F1 score provides the best balance of minimizing both False Positive and False Negative results out of all of our models.
#
# We also see that it has a relatively high PR-AUC score of 0.865, meaning it should perform well across different thresholds, if future analysis and tuning required it.
#
# As a comparison to our original baseline, we can see that the corresponding accuracy score of 0.796 far exceeds the baseline of 0.54.  However, this improvement to the baseline was a trend seen generally across most models, and not particularly important compared to the more relevant F1 score metric.

# %%
# Generate the confusion matrix
conf_matrix = confusion_matrix(y_test, lr_best.predict(X_test))

#Extract false positives
lr_FP = conf_matrix[0][1]
#Extract false negatives
lr_FN = conf_matrix[1][0]

# Plot the confusion matrix using ConfusionMatrixDisplay
ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=['0: Real', '1: Fake']).plot(values_format='d', cmap='Blues')
plt.title('Logistic Regression Model Confusion Matrix')
plt.ylabel('True Class')
plt.xlabel('Predicted Class')
plt.grid(False)
plt.show()

# %% [markdown]
# In order to interpret the F1 scores in a more explicit way, we will plot the confusion matrices for all the remaining models for later discussions:

# %%
# Generate the confusion matrix
nb_conf_matrix = confusion_matrix(y_test, nb_best.predict(X_test))
dt_conf_matrix = confusion_matrix(y_test, dt_best.predict(X_test))
svc_conf_matrix = confusion_matrix(y_test, svc_best.predict(X_test))

# Create a figure for subplots
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

# Plot each confusion matrix
ConfusionMatrixDisplay(confusion_matrix=nb_conf_matrix, display_labels=['0: Real', '1: Fake']).plot(values_format='d', cmap='Blues', ax=ax[0])
ax[0].set_title('Naive Bayes Confusion Matrix')
ax[0].set_ylabel('True Class')
ax[0].set_xlabel('Predicted Class')
ax[0].grid(False)

ConfusionMatrixDisplay(confusion_matrix=dt_conf_matrix, display_labels=['0: Real', '1: Fake']).plot(values_format='d', cmap='Blues', ax=ax[1])
ax[1].set_title('Decision Tree Confusion Matrix')
ax[1].set_ylabel('True Class')
ax[1].set_xlabel('Predicted Class')
ax[1].grid(False)

ConfusionMatrixDisplay(confusion_matrix=svc_conf_matrix, display_labels=['0: Real', '1: Fake']).plot(values_format='d', cmap='Blues', ax=ax[2])
ax[2].set_title('SVC Confusion Matrix')
ax[2].set_ylabel('True Class')
ax[2].set_xlabel('Predicted Class')
ax[2].grid(False)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# <a id="section3"></a>
# # Part 3: Modelling with Recurrent Neural Network (RNN) Model

# %% [markdown]
# <a id="section3A"></a>
# ## 3A: Motivation

# %% [markdown]
# As we can see, even after tuning hyperparameters to extract the best models, we had a best case scenario of 0.775 for the F1 score.
#
# With a maximum possible score of 1, there is definitely still room for improvement.
#
# The limitations of using non-neural networking is that we are processing the text into numbers that only represent their frequency and uniqueness to the text. The challenge of detecting fake news is that both fake and real news can often contain much of the same content, and be written in similar syntax.  They may only be separate subtle changes in context, order of facts and language (such as DID vs DID NOT), and less commonly these days by improper punctuation or spelling, as well as sensationalist vocabulary.

# %% [markdown]
# The complexities of assesing subtle contextual differences in large bodies of text, and the nuance between detecting fake and real news is a challenge that is best approached with using the Natural Language Processing (NLP) capabilities of a more complex Recurrent Neural Network (RNN) models, which is better suited to learn and interpet subtle patterns and the context of words in a sentence, paragraph, or entire article.

# %% [markdown]
# Additionally, though not shown in this jupyter notebook, trial and error showed that all performance metrics improved with:
#
# 1. Increased number of samples.
# 2. Using the tokenized TEXT data as the input to the model, instead of just the tokenized TITLE data.
#
# However, these 2 items also greatly increased processing time to unrealistic wait times for the previous models.

# %% [markdown]
# This next section focuses on developing and training a recurrent neural network model to improve performance by:
# 1. Better learning the subtle differences between Fake and Real news.
# 2. Improving the ability of the model to analyse large and complex datasets with less run time.

# %% [markdown]
# <a id="section3B"></a>
# ## 3B: Additional Preprocessing of X and y Dataframes

# %% [markdown]
# The first step is to perform additional preprocessing on the X and y dataframes into formats that are appropriate for the RNN models available within python.

# %% [markdown]
# ### i) Recreate X and y matrices
# This time we will take the lemmatized text column, in place of lemmatized title.

# %%
#First join tokenized words back into a string, separating with spaces, as is required for tokenizing using Scikit Learn

X = [' '.join(token) for token in df['Lemmatized Text']]
y = df['Fake']

# %% [markdown]
# ### ii) Tokenize the X dataframe and calculate vocabulary size
# Vocabulary size will be used below to re-initialize the tokenizer.

# %%
# Initialize the Tokenizer
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X)

# Size of the Vocabulary
vocab_size = len(tokenizer.word_index) + 1  #Adding 1 because index 0 is reserved

print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 26351

# %% [markdown]
# ### iii) Calculate the max sample length
# This will be used in the next step to ensure all sequences have a consistent length, as required for neural network processing

# %%
# Tokenize the text
sequences = tokenizer.texts_to_sequences(X)

# Calculate the length of each sequence
sequence_lengths = [len(seq) for seq in sequences]

# Determine an appropriate max_length
# For example, set max_length to the 90th percentile of sequence lengths
max_length = int(np.percentile(sequence_lengths, 90))

print("Chosen max_length:", max_length)
# Out:
# Chosen max_length: 630

# %% [markdown]
# ### iv) Re-initalize Tokenizer and pad the dataframe
# Tokenizer: This is done to ensure that the vocabulary size and ID remains consistent between training and test data tokenization.
#
# Padding: This done to ensure that each sample is a consistent size, which is required for efficient batch processing. It is set to the max sample length we calculated above.

# %%
# Re-initialize the tokenizer with the vocabulary size
tokenizer = Tokenizer(num_words=vocab_size)
tokenizer.fit_on_texts(X)

# Convert texts to sequences
sequences = tokenizer.texts_to_sequences(X)

# Pad the sequences
padded_sequences = pad_sequences(sequences, maxlen=max_length)

# %% [markdown]
# ### v) Recreate x using the pre-processed dataframe

# %%
X = padded_sequences

# %%
X
# Out:
# array([[    0,     0,     0, ...,   128,   724,   414],
#        [    0,     0,     0, ...,   234,   499,    72],
#        [    0,     0,     0, ...,    20,   273,  2972],
#        ...,
#        [    0,     0,     0, ...,   823, 26345, 26346],
#        [    0,     0,     0, ...,  1041,  3990,   401],
#        [    0,     0,     0, ...,   492,   141,  7560]])

# %% [markdown]
# ### vi) Convert y to an array
# This is required for neural network processing.

# %%
y = df['Fake'].values

# %% [markdown]
# ### vii) Split the newly tokenized X dataframe

# %%
#Create index trackers (idx_train and idx_test) so that we can compare final results with the original raw text entries

X_train, X_test, y_train, y_test, idx_train, idx_test = train_test_split(X, y, df.index, random_state=22)

# %% [markdown]
# Check the size of the training sets to make sure they have been padded to the max length.

# %%
print("Training set size:", X_train.shape)
print("Testing set size:", X_test.shape)
# Out:
# Training set size: (750, 630)
# Testing set size: (250, 630)

# %% [markdown]
# <a id="section3C"></a>
# ## 3C: Cross Validate and Tune Model

# %% [markdown]
# ### i) Set Embedding Dimensions
# Embedding is the process which converts tokenized words into dense vectors of fixed size, which is the numerical input required for RNN models.
#
# Seeting the embedding dimension to 50 means that each word is represented in a 50 dimensional space that captures difference semantic and syntatic information about that word in the context of other words around it, which is then processed by the neural network.
#
# 50 is selected somewhat arbitrarily as a starting point to trial.

# %%
embedding_dim = 50

# %% [markdown]
# ### ii) Compile Sequential Recurrent Neural Network (RNN) Model

# %% [markdown]
# Below is the framework of the neural network used to process our text data.
# It is kept fairly simple with only 3 layers:
# - 1x Embedding layer to vectorize the text as described above.
# - 1x Long Short-Term Model (LSTM) with 32 neurons to analyse patterns. LSTM is chosen as it is known to be useful for recognizing sequences in data, such as there are in text.
# - 1x Dense output layer with sigmoid activation.  Sigmoid is a method for translating the probabilities that the model calculates into one of our two  binary classifiers (Real, Fake).
#
# The model is built with the following parameters:
# - Optimizing algorithm called 'Adam'
#     - This controls how quickly the neural network learns at each step, to help it converge to the correct answer as quickly as possible.
# - Minimize the binary cross-entropy loss
#     - This a setting commonly used for binary classification tasks.
#     - It represents a logarithmic distance of the model output from the two classes (0 and 1).  The smaller the distance of each point, the more accurate the model is at correctly predicting the sample's class.

# %%
#Build a function to be able to run the RNN model through GridSearchCV.  
#Input is neurons, which will the parameter to alter
#Select random seed 42 to make sure results are as repeatable as possible
tf.random.set_seed(42)

def build_rnn_model(neurons):
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_length))
    model.add(LSTM(neurons))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy',Precision(), Recall()])
    return model

# %%
#Instantiate the model
rnn_model = KerasClassifier(build_fn=build_rnn_model)
                        
#Define parameters for Grid Search
params = {'neurons': [5, 16, 32],
          'epochs': [5,10]}

#Define Grid
rnn_grid = GridSearchCV(estimator = rnn_model,
                        param_grid=params,
                        scoring = 'f1')

# %%
#Fit Model
rnn_start_time = time.time()
rnn_grid.fit(X_train, y_train)
rnn_duration = time.time() - rnn_start_time
# Out:
# Epoch 1/5
# 19/19 [==============================] - 3s 99ms/step - loss: 0.6867 - accuracy: 0.6483 - precision: 0.6557 - recall: 0.3213
# Epoch 2/5
# 19/19 [==============================] - 2s 100ms/step - loss: 0.6472 - accuracy: 0.7633 - precision: 1.0000 - recall: 0.4297
# Epoch 3/5
# 19/19 [==============================] - 2s 108ms/step - loss: 0.5742 - accuracy: 0.8467 - precision: 1.0000 - recall: 0.6305
# Epoch 4/5
# 19/19 [==============================] - 2s 99ms/step - loss: 0.4574 - accuracy: 0.9500 - precision: 1.0000 - recall: 0.8795
# Epoch 5/5
# 19/19 [==============================] - 2s 99ms/step - loss: 0.3373 - accuracy: 0.9983 - precision: 1.0000 - recall: 0.9960
# 5/5 [==============================] - 0s 19ms/step
# Epoch 1/5
# 19/19 [==============================] - 3s 93ms/step - loss: 0.6782 - accuracy: 0.6983 - precision_1: 0.6839 - recall_1: 0.4454
# Epoch 2/5
# 19/19 [==============================] - 2s 97ms/step - loss: 0.6150 - accuracy: 0.8033 - precision_1: 1.0000 - recall_1: 0.5042
# Epoch 3/5
# 19/19 [==============================] - 2s 98ms/step - loss: 0.5155 - accuracy: 0.8433 - precision_1: 1.0000 - recall_1: 0.6050
# Epoch 4/5
# 19/19 [==============================] - 2s 98ms/step - loss: 0.3766 - accuracy: 0.9417 - precision_1: 1.0000 - recall_1: 0.8529
# Epoch 5/5
# 19/19 [==============================] - 2s 105ms/step - loss: 0.2493 - accuracy: 0.9967 - precision_1: 1.0000 - recall_1: 0.9916
# 5/5 [==============================] - 0s 21ms/step
# Epoch 1/5
# 19/19 [==============================] - 3s 94ms/step - loss: 0.6846 - accuracy: 0.6700 - precision_2: 0.6930 - recall_2: 0.3264
# Epoch 2/5
# 19/19 [==============================] - 2s 95ms/step - loss: 0.6430 - accuracy: 0.7567 - precision_2: 1.0000 - recall_2: 0.3967
# Epoch 3/5
# 19/19 [==============================] - 2s 97ms/step - loss: 0.5743 - accuracy: 0.8200 - precision_2: 1.0000 - recall_2: 0.5537
# Epoch 4/5
# 19/19 [==============================] - 2s 93ms/step - loss: 0.4648 - accuracy: 0.8950 - precision_2: 1.0000 - recall_2: 0.7397
# Epoch 5/5
# 19/19 [==============================] - 2s 97ms/step - loss: 0.3389 - accuracy: 0.9600 - precision_2: 1.0000 - recall_2: 0.9008
# 5/5 [==============================] - 0s 19ms/step
# Epoch 1/5
# 19/19 [==============================] - 3s 99ms/step - loss: 0.6822 - accuracy: 0.6700 - precision_3: 0.6912 - recall_3: 0.3760
# Epoch 2/5
# 19/19 [==============================] - 2s 104ms/step - loss: 0.6369 - accuracy: 0.7483 - precision_3: 1.0000 - recall_3: 0.3960
# Epoch 3/5
# 19/19 [==============================] - 2s 94ms/step - loss: 0.5579 - accuracy: 0.8550 - precision_3: 1.0000 - recall_3: 0.6520
# Epoch 4/5
# 19/19 [==============================] - 2s 96ms/step - loss: 0.4304 - accuracy: 0.9267 - precision_3: 1.0000 - recall_3: 0.8240
# Epoch 5/5
# 19/19 [==============================] - 2s 92ms/step - loss: 0.2887 - accuracy: 0.9717 - precision_3: 1.0000 - recall_3: 0.9320
# 5/5 [==============================] - 0s 20ms/step
# Epoch 1/5
# 19/19 [==============================] - 3s 91ms/step - loss: 0.6852 - accuracy: 0.6983 - precision_4: 0.7394 - recall_4: 0.4217
# Epoch 2/5
# 19/19 [==============================] - 2s 95ms/step - loss: 0.6510 - accuracy: 0.7650 - precision_4: 1.0000 - recall_4: 0.4337
# Epoch 3/5
# 19/19 [==============================] - 2s 98ms/step - loss: 0.5839 - accuracy: 0.8083 - precision_4: 1.0000 - recall_4: 0.5382
# Epoch 4/5
# 19/19 [==============================] - 2s 99ms/step - loss: 0.4766 - accuracy: 0.9017 - precision_4: 1.0000 - recall_4: 0.7631
# Epoch 5/5
# 19/19 [==============================] - 2s 96ms/step - loss: 0.3740 - accuracy: 0.9900 - precision_4: 1.0000 - recall_4: 0.9759
# 5/5 [==============================] - 0s 18ms/step
# Epoch 1/5
# 19/19 [==============================] - 3s 93ms/step - loss: 0.6868 - accuracy: 0.6267 - precision_5: 0.6812 - recall_5: 0.1888
# Epoch 2/5
# 19/19 [==============================] - 2s 97ms/step - loss: 0.6467 - accuracy: 0.6733 - precision_5: 1.0000 - recall_5: 0.2129
# Epoch 3/5
# 19/19 [==============================] - 2s 94ms/step - loss: 0.5008 - accuracy: 0.7233 - precision_5: 1.0000 - recall_5: 0.3333
# Epoch 4/5
# 19/19 [==============================] - 2s 95ms/step - loss: 0.2809 - accuracy: 0.9517 - precision_5: 1.0000 - recall_5: 0.8835
# Epoch 5/5
# 19/19 [==============================] - 2s 117ms/step - loss: 0.2032 - accuracy: 0.9883 - precision_5: 1.0000 - recall_5: 0.9719
# 5/5 [==============================] - 0s 27ms/step
# Epoch 1/5
# 19/19 [==============================] - 5s 134ms/step - loss: 0.6799 - accuracy: 0.6267 - precision_6: 0.6000 - recall_6: 0.1765
# Epoch 2/5
# 19/19 [==============================] - 2s 105ms/step - loss: 0.5951 - accuracy: 0.6517 - precision_6: 1.0000 - recall_6: 0.1218
# Epoch 3/5
# 19/19 [==============================] - 2s 98ms/step - loss: 0.3433 - accuracy: 0.8517 - precision_6: 1.0000 - recall_6: 0.6261
# Epoch 4/5
# 19/19 [==============================] - 2s 103ms/step - loss: 0.1649 - accuracy: 0.9950 - precision_6: 1.0000 - recall_6: 0.9874
# Epoch 5/5
# 19/19 [==============================] - 2s 98ms/step - loss: 0.1080 - accuracy: 0.9983 - precision_6: 1.0000 - recall_6: 0.9958
# 5/5 [==============================] - 0s 21ms/step
# Epoch 1/5
# 19/19 [==============================] - 3s 101ms/step - loss: 0.6837 - accuracy: 0.5933 - precision_7: 0.4762 - recall_7: 0.0826
# Epoch 2/5
# 19/19 [==============================] - 2s 107ms/step - loss: 0.6141 - accuracy: 0.5983 - precision_7: 1.0000 - recall_7: 0.0041
# Epoch 3/5
# 19/19 [==============================] - 2s 99ms/step - loss: 0.3968 - accuracy: 0.8383 - precision_7: 1.0000 - recall_7: 0.5992
# Epoch 4/5
# 19/19 [==============================] - 2s 99ms/step - loss: 0.2072 - accuracy: 0.9933 - precision_7: 0.9958 - recall_7: 0.9876
# Epoch 5/5
# 19/19 [==============================] - 2s 97ms/step - loss: 0.1468 - accuracy: 0.9967 - precision_7: 1.0000 - recall_7: 0.9917
# 5/5 [==============================] - 0s 23ms/step
# Epoch 1/5
# 19/19 [==============================] - 3s 98ms/step - loss: 0.6832 - accuracy: 0.6250 - precision_8: 0.6923 - recall_8: 0.1800
# Epoch 2/5
# 19/19 [==============================] - 2s 98ms/step - loss: 0.6213 - accuracy: 0.6567 - precision_8: 1.0000 - recall_8: 0.1760
# Epoch 3/5
# 19/19 [==============================] - 2s 98ms/step - loss: 0.4208 - accuracy: 0.8467 - precision_8: 1.0000 - recall_8: 0.6320
# Epoch 4/5
# 19/19 [==============================] - 2s 113ms/step - loss: 0.2473 - accuracy: 0.9833 - precision_8: 1.0000 - recall_8: 0.9600
# Epoch 5/5
# 19/19 [==============================] - 2s 102ms/step - loss: 0.1800 - accuracy: 0.9983 - precision_8: 1.0000 - recall_8: 0.9960
# 5/5 [==============================] - 0s 27ms/step
# Epoch 1/5
# 19/19 [==============================] - 3s 101ms/step - loss: 0.6835 - accuracy: 0.5983 - precision_9: 0.5526 - recall_9: 0.1687
# Epoch 2/5
# 19/19 [==============================] - 2s 99ms/step - loss: 0.6229 - accuracy: 0.6183 - precision_9: 1.0000 - recall_9: 0.0803
# Epoch 3/5
# 19/19 [==============================] - 2s 102ms/step - loss: 0.4360 - accuracy: 0.7967 - precision_9: 1.0000 - recall_9: 0.5100
# Epoch 4/5
# 19/19 [==============================] - 2s 98ms/step - loss: 0.2287 - accuracy: 0.9883 - precision_9: 0.9959 - recall_9: 0.9759
# Epoch 5/5
# 19/19 [==============================] - 2s 100ms/step - loss: 0.1543 - accuracy: 0.9983 - precision_9: 0.9960 - recall_9: 1.0000
# 5/5 [==============================] - 0s 25ms/step
# Epoch 1/5
# 19/19 [==============================] - 4s 114ms/step - loss: 0.6822 - accuracy: 0.6367 - precision_10: 0.6824 - recall_10: 0.2329
# Epoch 2/5
# 19/19 [==============================] - 2s 116ms/step - loss: 0.5950 - accuracy: 0.6133 - precision_10: 1.0000 - recall_10: 0.0683
# Epoch 3/5
# 19/19 [==============================] - 2s 115ms/step - loss: 0.3342 - accuracy: 0.9000 - precision_10: 1.0000 - recall_10: 0.7590
# Epoch 4/5
# 19/19 [==============================] - 2s 119ms/step - loss: 0.1711 - accuracy: 0.9967 - precision_10: 1.0000 - recall_10: 0.9920
# Epoch 5/5
# 19/19 [==============================] - 2s 118ms/step - loss: 0.1013 - accuracy: 1.0000 - precision_10: 1.0000 - recall_10: 1.0000
# 5/5 [==============================] - 0s 31ms/step
# Epoch 1/5
# 19/19 [==============================] - 4s 123ms/step - loss: 0.6828 - accuracy: 0.6000 - precision_11: 0.4545 - recall_11: 0.0420
# Epoch 2/5
# 19/19 [==============================] - 2s 113ms/step - loss: 0.6034 - accuracy: 0.6150 - precision_11: 1.0000 - recall_11: 0.0294
# Epoch 3/5
# 19/19 [==============================] - 2s 114ms/step - loss: 0.3791 - accuracy: 0.8817 - precision_11: 1.0000 - recall_11: 0.7017
# Epoch 4/5
# 19/19 [==============================] - 2s 112ms/step - loss: 0.1745 - accuracy: 0.9850 - precision_11: 1.0000 - recall_11: 0.9622
# Epoch 5/5
# 19/19 [==============================] - 2s 111ms/step - loss: 0.0933 - accuracy: 0.9967 - precision_11: 1.0000 - recall_11: 0.9916
# 5/5 [==============================] - 0s 30ms/step
# Epoch 1/5
# 19/19 [==============================] - 4s 110ms/step - loss: 0.6819 - accuracy: 0.6250 - precision_12: 0.6545 - recall_12: 0.1488
# Epoch 2/5
# 19/19 [==============================] - 2s 118ms/step - loss: 0.5906 - accuracy: 0.6400 - precision_12: 1.0000 - recall_12: 0.1074
# Epoch 3/5
# 19/19 [==============================] - 2s 119ms/step - loss: 0.3111 - accuracy: 0.9150 - precision_12: 1.0000 - recall_12: 0.7893
# Epoch 4/5
# 19/19 [==============================] - 2s 111ms/step - loss: 0.1706 - accuracy: 0.9917 - precision_12: 1.0000 - recall_12: 0.9793
# Epoch 5/5
# 19/19 [==============================] - 2s 109ms/step - loss: 0.1009 - accuracy: 0.9983 - precision_12: 1.0000 - recall_12: 0.9959
# 5/5 [==============================] - 0s 30ms/step
# Epoch 1/5
# 19/19 [==============================] - 5s 130ms/step - loss: 0.6840 - accuracy: 0.5717 - precision_13: 0.3793 - recall_13: 0.0440
# Epoch 2/5
# 19/19 [==============================] - 3s 135ms/step - loss: 0.6223 - accuracy: 0.5983 - precision_13: 1.0000 - recall_13: 0.0360
# Epoch 3/5
# 19/19 [==============================] - 3s 144ms/step - loss: 0.3798 - accuracy: 0.8150 - precision_13: 1.0000 - recall_13: 0.5560
# Epoch 4/5
# 19/19 [==============================] - 3s 136ms/step - loss: 0.2296 - accuracy: 0.9950 - precision_13: 1.0000 - recall_13: 0.9880
# Epoch 5/5
# 19/19 [==============================] - 3s 143ms/step - loss: 0.1168 - accuracy: 0.9950 - precision_13: 1.0000 - recall_13: 0.9880
# 5/5 [==============================] - 0s 34ms/step
# Epoch 1/5
# 19/19 [==============================] - 4s 131ms/step - loss: 0.6798 - accuracy: 0.6733 - precision_14: 0.8442 - recall_14: 0.2610
# Epoch 2/5
# 19/19 [==============================] - 3s 136ms/step - loss: 0.5929 - accuracy: 0.6333 - precision_14: 1.0000 - recall_14: 0.1165
# Epoch 3/5
# 19/19 [==============================] - 3s 135ms/step - loss: 0.3232 - accuracy: 0.8867 - precision_14: 1.0000 - recall_14: 0.7269
# Epoch 4/5
# 19/19 [==============================] - 3s 135ms/step - loss: 0.1392 - accuracy: 0.9950 - precision_14: 1.0000 - recall_14: 0.9880
# Epoch 5/5
# 19/19 [==============================] - 2s 129ms/step - loss: 0.0792 - accuracy: 0.9967 - precision_14: 1.0000 - recall_14: 0.9920
# 5/5 [==============================] - 0s 34ms/step
# Epoch 1/10
# 19/19 [==============================] - 4s 100ms/step - loss: 0.6884 - accuracy: 0.6533 - precision_15: 0.6376 - recall_15: 0.3815
# Epoch 2/10
# 19/19 [==============================] - 2s 104ms/step - loss: 0.6635 - accuracy: 0.7750 - precision_15: 1.0000 - recall_15: 0.4578
# Epoch 3/10
# 19/19 [==============================] - 3s 133ms/step - loss: 0.6197 - accuracy: 0.8100 - precision_15: 1.0000 - recall_15: 0.5422
# Epoch 4/10
# 19/19 [==============================] - 2s 111ms/step - loss: 0.5415 - accuracy: 0.8633 - precision_15: 1.0000 - recall_15: 0.6707
# Epoch 5/10
# 19/19 [==============================] - 2s 104ms/step - loss: 0.4244 - accuracy: 0.9133 - precision_15: 1.0000 - recall_15: 0.7912
# Epoch 6/10
# 19/19 [==============================] - 2s 102ms/step - loss: 0.3166 - accuracy: 0.9533 - precision_15: 1.0000 - recall_15: 0.8876
# Epoch 7/10
# 19/19 [==============================] - 2s 105ms/step - loss: 0.2483 - accuracy: 0.9933 - precision_15: 1.0000 - recall_15: 0.9839
# Epoch 8/10
# 19/19 [==============================] - 2s 105ms/step - loss: 0.2040 - accuracy: 0.9983 - precision_15: 1.0000 - recall_15: 0.9960
# Epoch 9/10
# 19/19 [==============================] - 2s 100ms/step - loss: 0.1719 - accuracy: 1.0000 - precision_15: 1.0000 - recall_15: 1.0000
# Epoch 10/10
# 19/19 [==============================] - 2s 96ms/step - loss: 0.1468 - accuracy: 1.0000 - precision_15: 1.0000 - recall_15: 1.0000
# 5/5 [==============================] - 0s 23ms/step
# Epoch 1/10
# 19/19 [==============================] - 3s 102ms/step - loss: 0.6879 - accuracy: 0.6900 - precision_16: 0.7097 - recall_16: 0.3697
# Epoch 2/10
# 19/19 [==============================] - 2s 104ms/step - loss: 0.6668 - accuracy: 0.7567 - precision_16: 1.0000 - recall_16: 0.3866
# Epoch 3/10
# 19/19 [==============================] - 2s 99ms/step - loss: 0.6293 - accuracy: 0.7717 - precision_16: 1.0000 - recall_16: 0.4244
# Epoch 4/10
# 19/19 [==============================] - 2s 97ms/step - loss: 0.5608 - accuracy: 0.8150 - precision_16: 1.0000 - recall_16: 0.5336
# Epoch 5/10
# 19/19 [==============================] - 2s 99ms/step - loss: 0.4672 - accuracy: 0.8950 - precision_16: 1.0000 - recall_16: 0.7353
# Epoch 6/10
# 19/19 [==============================] - 2s 96ms/step - loss: 0.3780 - accuracy: 0.9733 - precision_16: 1.0000 - recall_16: 0.9328
# Epoch 7/10
# 19/19 [==============================] - 2s 98ms/step - loss: 0.3136 - accuracy: 0.9983 - precision_16: 1.0000 - recall_16: 0.9958
# Epoch 8/10
# 19/19 [==============================] - 2s 99ms/step - loss: 0.2696 - accuracy: 1.0000 - precision_16: 1.0000 - recall_16: 1.0000
# Epoch 9/10
# 19/19 [==============================] - 2s 97ms/step - loss: 0.2357 - accuracy: 1.0000 - precision_16: 1.0000 - recall_16: 1.0000
# Epoch 10/10
# 19/19 [==============================] - 2s 108ms/step - loss: 0.2067 - accuracy: 1.0000 - precision_16: 1.0000 - recall_16: 1.0000
# 5/5 [==============================] - 0s 21ms/step
# Epoch 1/10
# 19/19 [==============================] - 3s 94ms/step - loss: 0.6896 - accuracy: 0.6317 - precision_17: 0.6061 - recall_17: 0.2479
# Epoch 2/10
# 19/19 [==============================] - 2s 94ms/step - loss: 0.6719 - accuracy: 0.7117 - precision_17: 1.0000 - recall_17: 0.2851
# Epoch 3/10
# 19/19 [==============================] - 2s 99ms/step - loss: 0.6372 - accuracy: 0.7533 - precision_17: 1.0000 - recall_17: 0.3884
# Epoch 4/10
# 19/19 [==============================] - 2s 94ms/step - loss: 0.5649 - accuracy: 0.7800 - precision_17: 1.0000 - recall_17: 0.4545
# Epoch 5/10
# 19/19 [==============================] - 2s 97ms/step - loss: 0.4585 - accuracy: 0.8617 - precision_17: 1.0000 - recall_17: 0.6570
# Epoch 6/10
# 19/19 [==============================] - 2s 97ms/step - loss: 0.3645 - accuracy: 0.9750 - precision_17: 1.0000 - recall_17: 0.9380
# Epoch 7/10
# 19/19 [==============================] - 2s 99ms/step - loss: 0.3081 - accuracy: 0.9950 - precision_17: 1.0000 - recall_17: 0.9876
# Epoch 8/10
# 19/19 [==============================] - 2s 114ms/step - loss: 0.2705 - accuracy: 0.9967 - precision_17: 1.0000 - recall_17: 0.9917
# Epoch 9/10
# 19/19 [==============================] - 2s 96ms/step - loss: 0.2412 - accuracy: 1.0000 - precision_17: 1.0000 - recall_17: 1.0000
# Epoch 10/10
# 19/19 [==============================] - 2s 95ms/step - loss: 0.2159 - accuracy: 1.0000 - precision_17: 1.0000 - recall_17: 1.0000
# 5/5 [==============================] - 0s 19ms/step
# Epoch 1/10
# 19/19 [==============================] - 3s 93ms/step - loss: 0.6834 - accuracy: 0.6867 - precision_18: 0.7818 - recall_18: 0.3440
# Epoch 2/10
# 19/19 [==============================] - 2s 97ms/step - loss: 0.6417 - accuracy: 0.7283 - precision_18: 1.0000 - recall_18: 0.3480
# Epoch 3/10
# 19/19 [==============================] - 2s 95ms/step - loss: 0.5591 - accuracy: 0.8250 - precision_18: 1.0000 - recall_18: 0.5800
# Epoch 4/10
# 19/19 [==============================] - 2s 95ms/step - loss: 0.4251 - accuracy: 0.9717 - precision_18: 1.0000 - recall_18: 0.9320
# Epoch 5/10
# 19/19 [==============================] - 2s 112ms/step - loss: 0.3090 - accuracy: 0.9983 - precision_18: 1.0000 - recall_18: 0.9960
# Epoch 6/10
# 19/19 [==============================] - 2s 99ms/step - loss: 0.2492 - accuracy: 0.9983 - precision_18: 1.0000 - recall_18: 0.9960
# Epoch 7/10
# 19/19 [==============================] - 2s 97ms/step - loss: 0.2137 - accuracy: 0.9983 - precision_18: 1.0000 - recall_18: 0.9960
# Epoch 8/10
# 19/19 [==============================] - 2s 96ms/step - loss: 0.1853 - accuracy: 1.0000 - precision_18: 1.0000 - recall_18: 1.0000
# Epoch 9/10
# 19/19 [==============================] - 2s 98ms/step - loss: 0.1591 - accuracy: 1.0000 - precision_18: 1.0000 - recall_18: 1.0000
# Epoch 10/10
# 19/19 [==============================] - 2s 96ms/step - loss: 0.1379 - accuracy: 1.0000 - precision_18: 1.0000 - recall_18: 1.0000
# 5/5 [==============================] - 0s 24ms/step
# Epoch 1/10
# 19/19 [==============================] - 3s 92ms/step - loss: 0.6869 - accuracy: 0.6317 - precision_19: 0.6061 - recall_19: 0.3213
# Epoch 2/10
# 19/19 [==============================] - 2s 104ms/step - loss: 0.6518 - accuracy: 0.7483 - precision_19: 1.0000 - recall_19: 0.3936
# Epoch 3/10
# 19/19 [==============================] - 2s 101ms/step - loss: 0.5864 - accuracy: 0.7967 - precision_19: 1.0000 - recall_19: 0.5100
# Epoch 4/10
# 19/19 [==============================] - 2s 95ms/step - loss: 0.4715 - accuracy: 0.8900 - precision_19: 1.0000 - recall_19: 0.7349
# Epoch 5/10
# 19/19 [==============================] - 2s 95ms/step - loss: 0.3407 - accuracy: 0.9817 - precision_19: 1.0000 - recall_19: 0.9558
# Epoch 6/10
# 19/19 [==============================] - 2s 95ms/step - loss: 0.2543 - accuracy: 0.9950 - precision_19: 1.0000 - recall_19: 0.9880
# Epoch 7/10
# 19/19 [==============================] - 2s 96ms/step - loss: 0.2060 - accuracy: 0.9983 - precision_19: 1.0000 - recall_19: 0.9960
# Epoch 8/10
# 19/19 [==============================] - 2s 95ms/step - loss: 0.1722 - accuracy: 1.0000 - precision_19: 1.0000 - recall_19: 1.0000
# Epoch 9/10
# 19/19 [==============================] - 2s 95ms/step - loss: 0.1457 - accuracy: 1.0000 - precision_19: 1.0000 - recall_19: 1.0000
# Epoch 10/10
# 19/19 [==============================] - 2s 95ms/step - loss: 0.1240 - accuracy: 1.0000 - precision_19: 1.0000 - recall_19: 1.0000
# 5/5 [==============================] - 0s 20ms/step
# Epoch 1/10
# 19/19 [==============================] - 4s 104ms/step - loss: 0.6835 - accuracy: 0.6767 - precision_20: 0.7835 - recall_20: 0.3052
# Epoch 2/10
# 19/19 [==============================] - 2s 111ms/step - loss: 0.6269 - accuracy: 0.7067 - precision_20: 1.0000 - recall_20: 0.2932
# Epoch 3/10
# 19/19 [==============================] - 2s 106ms/step - loss: 0.4508 - accuracy: 0.8233 - precision_20: 1.0000 - recall_20: 0.5743
# Epoch 4/10
# 19/19 [==============================] - 2s 105ms/step - loss: 0.2560 - accuracy: 0.9867 - precision_20: 1.0000 - recall_20: 0.9679
# Epoch 5/10
# 19/19 [==============================] - 2s 104ms/step - loss: 0.1838 - accuracy: 1.0000 - precision_20: 1.0000 - recall_20: 1.0000
# Epoch 6/10
# 19/19 [==============================] - 2s 105ms/step - loss: 0.1301 - accuracy: 0.9983 - precision_20: 1.0000 - recall_20: 0.9960
# Epoch 7/10
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0939 - accuracy: 1.0000 - precision_20: 1.0000 - recall_20: 1.0000
# Epoch 8/10
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0682 - accuracy: 1.0000 - precision_20: 1.0000 - recall_20: 1.0000
# Epoch 9/10
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0508 - accuracy: 1.0000 - precision_20: 1.0000 - recall_20: 1.0000
# Epoch 10/10
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0385 - accuracy: 1.0000 - precision_20: 1.0000 - recall_20: 1.0000
# 5/5 [==============================] - 0s 26ms/step
# Epoch 1/10
# 19/19 [==============================] - 3s 104ms/step - loss: 0.6863 - accuracy: 0.6283 - precision_21: 0.5974 - recall_21: 0.1933
# Epoch 2/10
# 19/19 [==============================] - 2s 104ms/step - loss: 0.6388 - accuracy: 0.6617 - precision_21: 1.0000 - recall_21: 0.1471
# Epoch 3/10
# 19/19 [==============================] - 2s 106ms/step - loss: 0.4678 - accuracy: 0.7100 - precision_21: 1.0000 - recall_21: 0.2689
# Epoch 4/10
# 19/19 [==============================] - 2s 112ms/step - loss: 0.2866 - accuracy: 0.9683 - precision_21: 1.0000 - recall_21: 0.9202
# Epoch 5/10
# 19/19 [==============================] - 2s 107ms/step - loss: 0.2014 - accuracy: 0.9967 - precision_21: 1.0000 - recall_21: 0.9916
# Epoch 6/10
# 19/19 [==============================] - 2s 104ms/step - loss: 0.1493 - accuracy: 0.9983 - precision_21: 1.0000 - recall_21: 0.9958
# Epoch 7/10
# 19/19 [==============================] - 2s 105ms/step - loss: 0.1151 - accuracy: 0.9983 - precision_21: 1.0000 - recall_21: 0.9958
# Epoch 8/10
# 19/19 [==============================] - 2s 106ms/step - loss: 0.0852 - accuracy: 0.9983 - precision_21: 1.0000 - recall_21: 0.9958
# Epoch 9/10
# 19/19 [==============================] - 2s 103ms/step - loss: 0.0699 - accuracy: 0.9983 - precision_21: 0.9958 - recall_21: 1.0000
# Epoch 10/10
# 19/19 [==============================] - 2s 102ms/step - loss: 0.0504 - accuracy: 1.0000 - precision_21: 1.0000 - recall_21: 1.0000
# 5/5 [==============================] - 0s 25ms/step
# Epoch 1/10
# 19/19 [==============================] - 4s 107ms/step - loss: 0.6815 - accuracy: 0.6383 - precision_22: 0.7193 - recall_22: 0.1694
# Epoch 2/10
# 19/19 [==============================] - 2s 102ms/step - loss: 0.6123 - accuracy: 0.6683 - precision_22: 1.0000 - recall_22: 0.1777
# Epoch 3/10
# 19/19 [==============================] - 2s 101ms/step - loss: 0.4127 - accuracy: 0.7833 - precision_22: 1.0000 - recall_22: 0.4628
# Epoch 4/10
# 19/19 [==============================] - 2s 101ms/step - loss: 0.2195 - accuracy: 0.9900 - precision_22: 1.0000 - recall_22: 0.9752
# Epoch 5/10
# 19/19 [==============================] - 2s 102ms/step - loss: 0.1491 - accuracy: 0.9983 - precision_22: 1.0000 - recall_22: 0.9959
# Epoch 6/10
# 19/19 [==============================] - 2s 103ms/step - loss: 0.1049 - accuracy: 1.0000 - precision_22: 1.0000 - recall_22: 1.0000
# Epoch 7/10
# 19/19 [==============================] - 2s 101ms/step - loss: 0.0732 - accuracy: 1.0000 - precision_22: 1.0000 - recall_22: 1.0000
# Epoch 8/10
# 19/19 [==============================] - 2s 100ms/step - loss: 0.0515 - accuracy: 1.0000 - precision_22: 1.0000 - recall_22: 1.0000
# Epoch 9/10
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0375 - accuracy: 1.0000 - precision_22: 1.0000 - recall_22: 1.0000
# Epoch 10/10
# 19/19 [==============================] - 2s 104ms/step - loss: 0.0289 - accuracy: 1.0000 - precision_22: 1.0000 - recall_22: 1.0000
# 5/5 [==============================] - 0s 25ms/step
# Epoch 1/10
# 19/19 [==============================] - 3s 96ms/step - loss: 0.6813 - accuracy: 0.6133 - precision_23: 0.6875 - recall_23: 0.1320
# Epoch 2/10
# 19/19 [==============================] - 2s 99ms/step - loss: 0.6096 - accuracy: 0.6517 - precision_23: 1.0000 - recall_23: 0.1640
# Epoch 3/10
# 19/19 [==============================] - 2s 99ms/step - loss: 0.3630 - accuracy: 0.8450 - precision_23: 1.0000 - recall_23: 0.6280
# Epoch 4/10
# 19/19 [==============================] - 2s 99ms/step - loss: 0.2157 - accuracy: 0.9833 - precision_23: 1.0000 - recall_23: 0.9600
# Epoch 5/10
# 19/19 [==============================] - 2s 99ms/step - loss: 0.1410 - accuracy: 0.9983 - precision_23: 1.0000 - recall_23: 0.9960
# Epoch 6/10
# 19/19 [==============================] - 2s 104ms/step - loss: 0.1048 - accuracy: 1.0000 - precision_23: 1.0000 - recall_23: 1.0000
# Epoch 7/10
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0794 - accuracy: 1.0000 - precision_23: 1.0000 - recall_23: 1.0000
# Epoch 8/10
# 19/19 [==============================] - 2s 100ms/step - loss: 0.0617 - accuracy: 1.0000 - precision_23: 1.0000 - recall_23: 1.0000
# Epoch 9/10
# 19/19 [==============================] - 2s 100ms/step - loss: 0.0487 - accuracy: 1.0000 - precision_23: 1.0000 - recall_23: 1.0000
# Epoch 10/10
# 19/19 [==============================] - 2s 98ms/step - loss: 0.0390 - accuracy: 1.0000 - precision_23: 1.0000 - recall_23: 1.0000
# 5/5 [==============================] - 0s 23ms/step
# Epoch 1/10
# 19/19 [==============================] - 3s 95ms/step - loss: 0.6849 - accuracy: 0.5967 - precision_24: 0.5556 - recall_24: 0.1406
# Epoch 2/10
# 19/19 [==============================] - 2s 97ms/step - loss: 0.6291 - accuracy: 0.6217 - precision_24: 1.0000 - recall_24: 0.0884
# Epoch 3/10
# 19/19 [==============================] - 2s 97ms/step - loss: 0.4380 - accuracy: 0.8300 - precision_24: 1.0000 - recall_24: 0.5904
# Epoch 4/10
# 19/19 [==============================] - 2s 109ms/step - loss: 0.2474 - accuracy: 0.9833 - precision_24: 0.9959 - recall_24: 0.9639
# Epoch 5/10
# 19/19 [==============================] - 2s 104ms/step - loss: 0.1678 - accuracy: 1.0000 - precision_24: 1.0000 - recall_24: 1.0000
# Epoch 6/10
# 19/19 [==============================] - 2s 113ms/step - loss: 0.1200 - accuracy: 1.0000 - precision_24: 1.0000 - recall_24: 1.0000
# Epoch 7/10
# 19/19 [==============================] - 2s 105ms/step - loss: 0.0905 - accuracy: 1.0000 - precision_24: 1.0000 - recall_24: 1.0000
# Epoch 8/10
# 19/19 [==============================] - 2s 102ms/step - loss: 0.0703 - accuracy: 1.0000 - precision_24: 1.0000 - recall_24: 1.0000
# Epoch 9/10
# 19/19 [==============================] - 2s 103ms/step - loss: 0.0561 - accuracy: 1.0000 - precision_24: 1.0000 - recall_24: 1.0000
# Epoch 10/10
# 19/19 [==============================] - 2s 103ms/step - loss: 0.0587 - accuracy: 0.9967 - precision_24: 1.0000 - recall_24: 0.9920
# 5/5 [==============================] - 0s 22ms/step
# Epoch 1/10
# 19/19 [==============================] - 4s 125ms/step - loss: 0.6826 - accuracy: 0.6400 - precision_25: 0.7260 - recall_25: 0.2129
# Epoch 2/10
# 19/19 [==============================] - 2s 115ms/step - loss: 0.6014 - accuracy: 0.6217 - precision_25: 1.0000 - recall_25: 0.0884
# Epoch 3/10
# 19/19 [==============================] - 2s 117ms/step - loss: 0.3457 - accuracy: 0.8667 - precision_25: 1.0000 - recall_25: 0.6787
# Epoch 4/10
# 19/19 [==============================] - 2s 115ms/step - loss: 0.1636 - accuracy: 0.9950 - precision_25: 1.0000 - recall_25: 0.9880
# Epoch 5/10
# 19/19 [==============================] - 2s 117ms/step - loss: 0.1038 - accuracy: 0.9950 - precision_25: 1.0000 - recall_25: 0.9880
# Epoch 6/10
# 19/19 [==============================] - 2s 116ms/step - loss: 0.0611 - accuracy: 1.0000 - precision_25: 1.0000 - recall_25: 1.0000
# Epoch 7/10
# 19/19 [==============================] - 2s 120ms/step - loss: 0.0376 - accuracy: 1.0000 - precision_25: 1.0000 - recall_25: 1.0000
# Epoch 8/10
# 19/19 [==============================] - 2s 124ms/step - loss: 0.0245 - accuracy: 1.0000 - precision_25: 1.0000 - recall_25: 1.0000
# Epoch 9/10
# 19/19 [==============================] - 2s 113ms/step - loss: 0.0172 - accuracy: 1.0000 - precision_25: 1.0000 - recall_25: 1.0000
# Epoch 10/10
# 19/19 [==============================] - 2s 115ms/step - loss: 0.0129 - accuracy: 1.0000 - precision_25: 1.0000 - recall_25: 1.0000
# 5/5 [==============================] - 0s 32ms/step
# Epoch 1/10
# 19/19 [==============================] - 4s 112ms/step - loss: 0.6803 - accuracy: 0.6267 - precision_26: 0.6296 - recall_26: 0.1429
# Epoch 2/10
# 19/19 [==============================] - 2s 115ms/step - loss: 0.5864 - accuracy: 0.6350 - precision_26: 1.0000 - recall_26: 0.0798
# Epoch 3/10
# 19/19 [==============================] - 2s 114ms/step - loss: 0.3187 - accuracy: 0.9100 - precision_26: 1.0000 - recall_26: 0.7731
# Epoch 4/10
# 19/19 [==============================] - 2s 122ms/step - loss: 0.1766 - accuracy: 0.9967 - precision_26: 1.0000 - recall_26: 0.9916
# Epoch 5/10
# 19/19 [==============================] - 2s 115ms/step - loss: 0.1577 - accuracy: 1.0000 - precision_26: 1.0000 - recall_26: 1.0000
# Epoch 6/10
# 19/19 [==============================] - 2s 114ms/step - loss: 0.0913 - accuracy: 1.0000 - precision_26: 1.0000 - recall_26: 1.0000
# Epoch 7/10
# 19/19 [==============================] - 2s 114ms/step - loss: 0.0657 - accuracy: 1.0000 - precision_26: 1.0000 - recall_26: 1.0000
# Epoch 8/10
# 19/19 [==============================] - 2s 113ms/step - loss: 0.0478 - accuracy: 1.0000 - precision_26: 1.0000 - recall_26: 1.0000
# Epoch 9/10
# 19/19 [==============================] - 2s 113ms/step - loss: 0.0351 - accuracy: 1.0000 - precision_26: 1.0000 - recall_26: 1.0000
# Epoch 10/10
# 19/19 [==============================] - 2s 113ms/step - loss: 0.0258 - accuracy: 1.0000 - precision_26: 1.0000 - recall_26: 1.0000
# 5/5 [==============================] - 0s 30ms/step
# Epoch 1/10
# 19/19 [==============================] - 4s 118ms/step - loss: 0.6815 - accuracy: 0.5983 - precision_27: 0.5106 - recall_27: 0.0992
# Epoch 2/10
# 19/19 [==============================] - 2s 116ms/step - loss: 0.6030 - accuracy: 0.6217 - precision_27: 1.0000 - recall_27: 0.0620
# Epoch 3/10
# 19/19 [==============================] - 2s 115ms/step - loss: 0.3420 - accuracy: 0.8733 - precision_27: 1.0000 - recall_27: 0.6860
# Epoch 4/10
# 19/19 [==============================] - 2s 114ms/step - loss: 0.1619 - accuracy: 0.9933 - precision_27: 1.0000 - recall_27: 0.9835
# Epoch 5/10
# 19/19 [==============================] - 2s 117ms/step - loss: 0.0813 - accuracy: 1.0000 - precision_27: 1.0000 - recall_27: 1.0000
# Epoch 6/10
# 19/19 [==============================] - 2s 117ms/step - loss: 0.0428 - accuracy: 1.0000 - precision_27: 1.0000 - recall_27: 1.0000
# Epoch 7/10
# 19/19 [==============================] - 2s 115ms/step - loss: 0.0222 - accuracy: 1.0000 - precision_27: 1.0000 - recall_27: 1.0000
# Epoch 8/10
# 19/19 [==============================] - 2s 129ms/step - loss: 0.0137 - accuracy: 0.9983 - precision_27: 0.9959 - recall_27: 1.0000
# Epoch 9/10
# 19/19 [==============================] - 2s 118ms/step - loss: 0.0196 - accuracy: 1.0000 - precision_27: 1.0000 - recall_27: 1.0000
# Epoch 10/10
# 19/19 [==============================] - 2s 116ms/step - loss: 0.0186 - accuracy: 0.9983 - precision_27: 1.0000 - recall_27: 0.9959
# 5/5 [==============================] - 0s 32ms/step
# Epoch 1/10
# 19/19 [==============================] - 4s 129ms/step - loss: 0.6805 - accuracy: 0.5967 - precision_28: 0.6111 - recall_28: 0.0880
# Epoch 2/10
# 19/19 [==============================] - 2s 131ms/step - loss: 0.5945 - accuracy: 0.6167 - precision_28: 1.0000 - recall_28: 0.0800
# Epoch 3/10
# 19/19 [==============================] - 3s 138ms/step - loss: 0.3292 - accuracy: 0.8700 - precision_28: 1.0000 - recall_28: 0.6880
# Epoch 4/10
# 19/19 [==============================] - 2s 129ms/step - loss: 0.1584 - accuracy: 0.9950 - precision_28: 1.0000 - recall_28: 0.9880
# Epoch 5/10
# 19/19 [==============================] - 2s 132ms/step - loss: 0.0623 - accuracy: 1.0000 - precision_28: 1.0000 - recall_28: 1.0000
# Epoch 6/10
# 19/19 [==============================] - 2s 130ms/step - loss: 0.0267 - accuracy: 1.0000 - precision_28: 1.0000 - recall_28: 1.0000
# Epoch 7/10
# 19/19 [==============================] - 3s 133ms/step - loss: 0.0155 - accuracy: 1.0000 - precision_28: 1.0000 - recall_28: 1.0000
# Epoch 8/10
# 19/19 [==============================] - 2s 130ms/step - loss: 0.0103 - accuracy: 1.0000 - precision_28: 1.0000 - recall_28: 1.0000
# Epoch 9/10
# 19/19 [==============================] - 3s 137ms/step - loss: 0.0073 - accuracy: 1.0000 - precision_28: 1.0000 - recall_28: 1.0000
# Epoch 10/10
# 19/19 [==============================] - 3s 138ms/step - loss: 0.0052 - accuracy: 1.0000 - precision_28: 1.0000 - recall_28: 1.0000
# 5/5 [==============================] - 0s 33ms/step
# Epoch 1/10
# 19/19 [==============================] - 4s 128ms/step - loss: 0.6769 - accuracy: 0.6200 - precision_29: 0.6780 - recall_29: 0.1606
# Epoch 2/10
# 19/19 [==============================] - 2s 129ms/step - loss: 0.5495 - accuracy: 0.6483 - precision_29: 1.0000 - recall_29: 0.1526
# Epoch 3/10
# 19/19 [==============================] - 2s 128ms/step - loss: 0.2831 - accuracy: 0.9583 - precision_29: 0.9956 - recall_29: 0.9036
# Epoch 4/10
# 19/19 [==============================] - 2s 131ms/step - loss: 0.1474 - accuracy: 0.9983 - precision_29: 1.0000 - recall_29: 0.9960
# Epoch 5/10
# 19/19 [==============================] - 3s 136ms/step - loss: 0.0807 - accuracy: 1.0000 - precision_29: 1.0000 - recall_29: 1.0000
# Epoch 6/10
# 19/19 [==============================] - 2s 129ms/step - loss: 0.0471 - accuracy: 1.0000 - precision_29: 1.0000 - recall_29: 1.0000
# Epoch 7/10
# 19/19 [==============================] - 2s 130ms/step - loss: 0.0345 - accuracy: 0.9983 - precision_29: 0.9960 - recall_29: 1.0000
# Epoch 8/10
# 19/19 [==============================] - 2s 130ms/step - loss: 0.0212 - accuracy: 1.0000 - precision_29: 1.0000 - recall_29: 1.0000
# Epoch 9/10
# 19/19 [==============================] - 2s 130ms/step - loss: 0.0150 - accuracy: 1.0000 - precision_29: 1.0000 - recall_29: 1.0000
# Epoch 10/10
# 19/19 [==============================] - 3s 133ms/step - loss: 0.0119 - accuracy: 1.0000 - precision_29: 1.0000 - recall_29: 1.0000
# 5/5 [==============================] - 0s 33ms/step
# Epoch 1/10
# 24/24 [==============================] - 4s 108ms/step - loss: 0.6813 - accuracy: 0.6973 - precision_30: 0.8509 - recall_30: 0.3160
# Epoch 2/10
# 24/24 [==============================] - 2s 101ms/step - loss: 0.6002 - accuracy: 0.7027 - precision_30: 1.0000 - recall_30: 0.2736
# Epoch 3/10
# 24/24 [==============================] - 2s 102ms/step - loss: 0.3485 - accuracy: 0.8613 - precision_30: 0.9951 - recall_30: 0.6645
# Epoch 4/10
# 24/24 [==============================] - 2s 101ms/step - loss: 0.1704 - accuracy: 0.9907 - precision_30: 0.9967 - recall_30: 0.9805
# Epoch 5/10
# 24/24 [==============================] - 2s 101ms/step - loss: 0.1038 - accuracy: 0.9973 - precision_30: 1.0000 - recall_30: 0.9935
# Epoch 6/10
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0703 - accuracy: 1.0000 - precision_30: 1.0000 - recall_30: 1.0000
# Epoch 7/10
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0493 - accuracy: 1.0000 - precision_30: 1.0000 - recall_30: 1.0000
# Epoch 8/10
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0357 - accuracy: 1.0000 - precision_30: 1.0000 - recall_30: 1.0000
# Epoch 9/10
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0280 - accuracy: 0.9987 - precision_30: 1.0000 - recall_30: 0.9967
# Epoch 10/10
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0352 - accuracy: 0.9973 - precision_30: 0.9935 - recall_30: 1.0000

# %%
#Extract hyperparameters from the best estimator
rnn_params = rnn_grid.best_params_
rnn_params_df = pd.DataFrame([rnn_params])
best_epochs = rnn_params_df.iloc[:,0].item()
best_neurons = rnn_params_df.iloc[:,1].item()

rnn_params
# Out:
# {'epochs': 10, 'neurons': 16}

# %% [markdown]
# <a id="section3D"></a>
# ## 3D: Model Review and Comparison

# %% [markdown]
# ### i) Evalute Best RNN Model Performance

# %%
display(Markdown(f"Based on the GridSearchCV method above, the optimal number for increasing our F1 score is {best_epochs} training epochs, and neurons for the LSTM layer is {best_neurons}.\n\n We will retrain our model using these parameters below so we can visualize and analyse its performance over the training epochs:"))
# Out:
# Based on the GridSearchCV method above, the optimal number for increasing our F1 score is 10 training epochs, and neurons for the LSTM layer is 16.
#
#  We will retrain our model using these parameters below so we can visualize and analyse its performance over the training epochs:

# %%
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_length))
model.add(LSTM(best_neurons))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy',Precision(), Recall()])

# %%
history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 24/24 [==============================] - 4s 124ms/step - loss: 0.6755 - accuracy: 0.6427 - precision_31: 0.7600 - recall_31: 0.1857 - val_loss: 0.6505 - val_accuracy: 0.5600 - val_precision_31: 1.0000 - val_recall_31: 0.0435
# Epoch 2/10
# 24/24 [==============================] - 3s 109ms/step - loss: 0.5332 - accuracy: 0.7200 - precision_31: 1.0000 - recall_31: 0.3160 - val_loss: 0.4691 - val_accuracy: 0.8560 - val_precision_31: 0.9647 - val_recall_31: 0.7130
# Epoch 3/10
# 24/24 [==============================] - 3s 115ms/step - loss: 0.2958 - accuracy: 0.9747 - precision_31: 1.0000 - recall_31: 0.9381 - val_loss: 0.4571 - val_accuracy: 0.8400 - val_precision_31: 0.9870 - val_recall_31: 0.6609
# Epoch 4/10
# 24/24 [==============================] - 3s 107ms/step - loss: 0.1865 - accuracy: 0.9960 - precision_31: 1.0000 - recall_31: 0.9902 - val_loss: 0.4236 - val_accuracy: 0.8640 - val_precision_31: 0.9765 - val_recall_31: 0.7217
# Epoch 5/10
# 24/24 [==============================] - 3s 107ms/step - loss: 0.1279 - accuracy: 0.9987 - precision_31: 1.0000 - recall_31: 0.9967 - val_loss: 0.3253 - val_accuracy: 0.8760 - val_precision_31: 0.8559 - val_recall_31: 0.8783
# Epoch 6/10
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0921 - accuracy: 0.9987 - precision_31: 1.0000 - recall_31: 0.9967 - val_loss: 0.2983 - val_accuracy: 0.8800 - val_precision_31: 0.8346 - val_recall_31: 0.9217
# Epoch 7/10
# 24/24 [==============================] - 3s 107ms/step - loss: 0.0674 - accuracy: 1.0000 - precision_31: 1.0000 - recall_31: 1.0000 - val_loss: 0.3122 - val_accuracy: 0.8800 - val_precision_31: 0.8455 - val_recall_31: 0.9043
# Epoch 8/10
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0508 - accuracy: 1.0000 - precision_31: 1.0000 - recall_31: 1.0000 - val_loss: 0.3020 - val_accuracy: 0.8760 - val_precision_31: 0.8231 - val_recall_31: 0.9304
# Epoch 9/10
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0399 - accuracy: 1.0000 - precision_31: 1.0000 - recall_31: 1.0000 - val_loss: 0.2988 - val_accuracy: 0.8880 - val_precision_31: 0.8537 - val_recall_31: 0.9130
# Epoch 10/10
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0331 - accuracy: 1.0000 - precision_31: 1.0000 - recall_31: 1.0000 - val_loss: 0.3102 - val_accuracy: 0.8720 - val_precision_31: 0.8268 - val_recall_31: 0.9130

# %% [markdown]
# Below we manually calculate the F1 score, since it is not part of Tensorflow metric database.

# %%
#Reset column names after epoch training
history_df = pd.DataFrame(history.history)
new_column_names = ['loss',
 'accuracy',
 'precision',
 'recall',
 'val_loss',
 'val_accuracy',
 'val_precision',
 'val_recall']
history_df.columns = new_column_names

# %%
# Calculating F1 score
history_df['f1_train'] = 2 * (history_df['precision'] * history_df['recall']) / (history_df['precision'] + history_df['recall'])
history_df['f1_val'] = 2 * (history_df['val_precision'] * history_df['val_recall']) / (history_df['val_precision'] + history_df['val_recall'])

# %% [markdown]
# Below we visualize the performance of the model over the training epochs based on each of our metrics.

# %%
epochs = range(1, len(history_df) + 1)

plt.figure(figsize=(15, 10))

# Plotting Accuracy
plt.subplot(2, 3, 1)
plt.plot(epochs, history_df['accuracy'], 'bo-', label='Train Accuracy')
plt.plot(epochs, history_df['val_accuracy'], 'ro-', label='Test Accuracy')
plt.title('Train and Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plotting Loss
plt.subplot(2, 3, 2)
plt.plot(epochs, history_df['loss'], 'bo-', label='Train Loss')
plt.plot(epochs, history_df['val_loss'], 'ro-', label='Test Loss')
plt.title('Train and Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plotting Precision
plt.subplot(2, 3, 3)
plt.plot(epochs, history_df['precision'], 'bo-', label='Train Precision')
plt.plot(epochs, history_df['val_precision'], 'ro-', label='Test Precision')
plt.title('Train and Test Precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()

# Plotting Recall
plt.subplot(2, 3, 4)
plt.plot(epochs, history_df['recall'], 'bo-', label='Train Recall')
plt.plot(epochs, history_df['val_recall'], 'ro-', label='Test Recall')
plt.title('Train and Test Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()

# Plotting F1 Score
plt.subplot(2, 3, 5)
plt.plot(epochs, history_df['f1_train'], 'bo-', label='Train F1 Score')
plt.plot(epochs, history_df['f1_val'], 'ro-', label='Test F1 Score')
plt.title('Train and Test F1 Score')
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Note that due to the nature of neural networks, these results will change slightly each time this notebook is run.
#
# However as we can see, despite the gridsearch method to find optimal paramters, the model starts to perform perfectly on all metrics when fitting the training data as the number of epochs increase, indicating that our model is starting to overfit after several epochs.
#
# As with most machine learning, the more the model starts to overfit the training data, the less well it generalizes on new unseen data, which we can see in the 'Train and Test Loss' graph, which shows that the Test loss starts to increase while the Train loss decreases, once the model starts overfitting.
#
# We want to choose the number of epochs that minimizes loss, and also maintains a good F1 score.  As we can see, the F1 score stays fairly constant or increases through to the end of the training, however this is just based on this dataset.  If the model can't generalize to new unseen data, it is not practically useful.
#
# Based on our time constraints, we will leave the model as is as it still performs better than the previous non-neural networks.  However recommended next steps are to tune the model further (such as reducing number of epochs) to ensure that the model can generalize better.  Further techniques for improving RNN model tuning are discussed in the associated README file under the Next Steps section.

# %% [markdown]
# As before, we also visualize the PR-AUC curve to see how the model fares with balancing recall and precision over different thresholds.

# %%
# Predict the probabilities
y_pred_probs = model.predict(X_test)

# Calculate precision and recall for various thresholds
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_probs)

# Calculate PR AUC
rnn_pr_auc = auc(recall, precision)

# Plot the PR curve
plt.figure()
plt.plot(recall, precision, label='PR Curve (AUC = %0.2f)' % rnn_pr_auc)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('RNN Model Precision-Recall Area Under Curve (PR-AUC)')
plt.legend(loc="lower left")
plt.show()
# Out:
# 8/8 [==============================] - 0s 23ms/step

# %% [markdown]
# ### ii) Compare RNN with non neural models

# %%
#Recheck metrics by predicting on X_test data, and converting probabilities to classes:
y_pred_prob = model.predict(X_test)
y_pred_class = (y_pred_prob > 0.5).astype(int)

# Score best estimator
rnn_accuracy = accuracy_score(y_test, y_pred_class)
rnn_recall = recall_score(y_test, y_pred_class)
rnn_precision = precision_score(y_test, y_pred_class)
rnn_f1 = f1_score(y_test, y_pred_class)
# Out:
# 8/8 [==============================] - 0s 27ms/step

# %%
#Append results to the model comparison dataframe:

rnn_report = {
    'Model': 'RNN',
    'Train Duration': rnn_duration,
    'Test Accuracy': rnn_accuracy,
    'Test Recall': rnn_recall,
    'Test Precision': rnn_precision,
    'Test F1': rnn_f1,
    'Test PR AUC': rnn_pr_auc}

rnn_report = pd.DataFrame([rnn_report])
results_df = pd.concat([results_df, rnn_report], ignore_index=True).round(3)
results_df
# Out:
#                  Model  Train Duration  Test Accuracy  Test Recall  \
# 0          Naive Bayes           0.339          0.744        0.583
# 1        Decision Tree           9.099          0.684        0.330
# 2  Logistic Regression           0.887          0.796        0.765
# 3                  SVC           2.132          0.784        0.635
# 4                  RNN         559.050          0.872        0.913
#
#    Test Precision  Test F1  Test PR AUC
# 0           0.807    0.677        0.826
# 1           0.950    0.490        0.817
# 2           0.786    0.775        0.865
# 3           0.859    0.730        0.867
# 4           0.827    0.868        0.954

# %%
display(Markdown(f"Based on the final comparison table, we can see that the RNN model has improved performance based on the F1 score of {rnn_f1:0.3f} compared to the best performing non-neural model Logistic Regression with an F1 score of {lr_f1:.3f}, as well as an improved PR-AUC score of {rnn_pr_auc: 0.03f} compared with {svc_pr_auc: 0.03f}."))
# Out:
# Based on the final comparison table, we can see that the RNN model has improved performance based on the F1 score of 0.868 compared to the best performing non-neural model Logistic Regression with an F1 score of 0.775, as well as an improved PR-AUC score of  0.954 compared with  0.867.

# %%
# Generate the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred_class)

#Extract false positives
rnn_FP = conf_matrix[0][1]
#Extract false negatives
rnn_FN = conf_matrix[1][0]

# Plot the confusion matrix 
ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=['0: Real', '1: Fake']).plot(values_format='d', cmap='Blues')
plt.title('RNN Model Confusion Matrix')
plt.ylabel('True Class')
plt.xlabel('Predicted Class')
plt.grid(False)
plt.show()

# %%
display(Markdown(f"Reviewing the confusion matrix, we can more clearly understand that the RNN model has changed the number of:\n\n - False Positives (Real news incorrectly identified as Fake) from {lr_FP} to {rnn_FP} \n\n - False Negatives (Fake news incorrectly identified as Real) from {lr_FN} to {rnn_FN} \n\nwhen compared with the best performing non neural network (Logistic Regression)."))
# Out:
# Reviewing the confusion matrix, we can more clearly understand that the RNN model has changed the number of:
#
#  - False Positives (Real news incorrectly identified as Fake) from 24 to 22
#
#  - False Negatives (Fake news incorrectly identified as Real) from 27 to 10
#
# when compared with the best performing non neural network (Logistic Regression).

# %% [markdown]
# <a id="section3E"></a>
# ### 3E: Deepdive RNN Model Performance and Limitations on a Sample

# %% [markdown]
# In order to see how our RNN model works on a real example, we can use the Lime Text Explainer package which identifies which features were most important in classifying a sample as real or fake.

# %% [markdown]
# The below steps are required to process the data to a format that is compatible with the Lime Package.

# %%
# Creating a reverse mapping from index to word
reverse_word_map = dict(map(reversed, tokenizer.word_index.items()))

# Function to convert a tokenized sequence back to words
def sequence_to_text(sequence):
    words = [reverse_word_map.get(token, '') for token in sequence]
    return ' '.join(words).strip()

# %%
# Define the prediction function
def predict_proba(texts):
    # Preprocess the texts: Convert texts to sequences
    sequences = tokenizer.texts_to_sequences(texts)

    # Pad the sequences
    padded_sequences = pad_sequences(sequences, maxlen=max_length)

    # Get prediction
    y_pred_prob = model.predict(padded_sequences)
    
    # Convert to 2D array with two columns
    return np.hstack((1 - y_pred_prob, y_pred_prob))

# %% [markdown]
# Now we will select a sample to analyse with the Lime Explainer.

# %%
#Extract sample to analyse
sample = 40

#Index of sample in original dataframe
index = idx_test[sample]

#Print the original text and class for this sample:
pd.DataFrame(df[['Title','Text','Fake']].iloc[index]).T
# Out:
#                                                  Title  \
# 582  Trump Warns Comey: Better Hope That There Are ...
#
#                                                   Text Fake
# 582  President Trump warned former FBI Director Jam...    0

# %% [markdown]
# We will put this sample through the Lime Explainer process, which analyses which words in this sample were deemed important by  our RNN model for classifying it as Fake or Real news.

# %%
# Convert the first sequence in X_test back to text
raw_text_example = sequence_to_text(X_test[sample])

# Create a LimeTextExplainer object
explainer = LimeTextExplainer(class_names=['Real', 'Fake']) 

# Explain the prediction of the first instance in X_test
explanation = explainer.explain_instance(raw_text_example, predict_proba)
# Out:
# 157/157 [==============================] - 4s 26ms/step

# %%
#Actual classification of the sample from original dataframe
actual_class = 'Real' if df['Fake'][index] == 0 else 'Fake'

#Predicted class
pred_class = 'Real' if y_pred_class[sample] == 0 else 'Fake' 

display(Markdown(f"This sample's actual class was **{actual_class}**, and its predicted value from the RNN model was **{pred_class}**."))
# Out:
# This sample's actual class was **Real**, and its predicted value from the RNN model was **Real**.

# %% [markdown]
# Below we can see a visualization from the Lime Explainer which depicts for which words in the sample influenced the Model's prediction of the result closer towards Fake or Real.
#
# The prediction probabilty shows what how likely our RNN model thought the sample was Real or Fake, and the scale on the right shows which words were had the most influence on each of these probabilites.
#
# This tool provides a good high level way to:
# - Visualize the limitations of our model.
# - Understand which words were important in either correctly or incorrectly classifying samples.
# - Assist in providing further insight to the public on how Natural Language Processing works and is influenced by the data it trains on.

# %%
# Display the explanation
explanation.show_in_notebook()
# Out:
# <html>
#         <meta http-equiv="content-type" content="text/html; charset=UTF8">
#         <head><script>var lime =
# /******/ (function(modules) { // webpackBootstrap
# /******/ 	// The module cache
# /******/ 	var installedModules = {};
# /******/
# /******/ 	// The require function
# /******/ 	function __webpack_require__(moduleId) {
# /******/
# /******/ 		// Check if module is in cache
# /******/ 		if(installedModules[moduleId])
# /******/ 			return installedModules[moduleId].exports;
# /******/
# /******/ 		// Create a new module (and put it into the cache)
# /******/ 		var module = installedModules[moduleId] = {
# /******/ 			exports: {},
# /******/ 			id: moduleId,
# /******/ 			loaded: false
# /******/ 		};
# /******/
# /******/ 		// Execute the module function
# /******/ 		modules[moduleId].call(module.exports, module, module.exports, __webpack_require__);
# /******/
# /******/ 		// Flag the module as loaded
# /******/ 		module.loaded = true;
# /******/
# /******/ 		// Return the exports of the module
# /******/ 		return module.exports;
# /******/ 	}
# /******/
# /******/
# /******/ 	// expose the modules object (__webpack_modules__)
# /******/ 	__webpack_require__.m = modules;
# /******/
# /******/ 	// expose the module cache
# /******/ 	__webpack_require__.c = installedModules;
# /******/
# /******/ 	// __webpack_public_path__
# /******/ 	__webpack_require__.p = "";
# /******/
# /******/ 	// Load entry module and return exports
# /******/ 	return __webpack_require__(0);
# /******/ })
# /************************************************************************/
# /******/ ([
# /* 0 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	/* WEBPACK VAR INJECTION */(function(global) {'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
# 	exports.PredictedValue = exports.PredictProba = exports.Barchart = exports.Explanation = undefined;
#
# 	var _explanation = __webpack_require__(1);
#
# 	var _explanation2 = _interopRequireDefault(_explanation);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _predict_proba = __webpack_require__(6);
#
# 	var _predict_proba2 = _interopRequireDefault(_predict_proba);
#
# 	var _predicted_value = __webpack_require__(7);
#
# 	var _predicted_value2 = _interopRequireDefault(_predicted_value);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	if (!global._babelPolyfill) {
# 	  __webpack_require__(8);
# 	}
#
# 	__webpack_require__(339);
#
# 	exports.Explanation = _explanation2.default;
# 	exports.Barchart = _bar_chart2.default;
# 	exports.PredictProba = _predict_proba2.default;
# 	exports.PredictedValue = _predicted_value2.default;
# 	//require('style-loader');
# 	/* WEBPACK VAR INJECTION */}.call(exports, (function() { return this; }())))
#
# /***/ }),
# /* 1 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
#
# 	var _slicedToArray = function () { function sliceIterator(arr, i) { var _arr = []; var _n = true; var _d = false; var _e = undefined; try { for (var _i = arr[Symbol.iterator](), _s; !(_n = (_s = _i.next()).done); _n = true) { _arr.push(_s.value); if (i && _arr.length === i) break; } } catch (err) { _d = true; _e = err; } finally { try { if (!_n && _i["return"]) _i["return"](); } finally { if (_d) throw _e; } } return _arr; } return function (arr, i) { if (Array.isArray(arr)) { return arr; } else if (Symbol.iterator in Object(arr)) { return sliceIterator(arr, i); } else { throw new TypeError("Invalid attempt to destructure non-iterable instance"); } }; }();
#
# 	var _d2 = __webpack_require__(2);
#
# 	var _d3 = _interopRequireDefault(_d2);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _lodash = __webpack_require__(4);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	function _classCallCheck(instance, Constructor) { if (!(instance instanceof Constructor)) { throw new TypeError("Cannot call a class as a function"); } }
#
# 	var Explanation = function () {
# 	  function Explanation(class_names) {
# 	    _classCallCheck(this, Explanation);
#
# 	    this.names = class_names;
# 	    if (class_names.length < 10) {
# 	      this.colors = _d3.default.scale.category10().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category10().domain((0, _lodash.range)(this.names.length));
# 	    } else {
# 	      this.colors = _d3.default.scale.category20().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category20().domain((0, _lodash.range)(this.names.length));
# 	    }
# 	  }
# 	  // exp: [(feature-name, weight), ...]
# 	  // label: int
# 	  // div: d3 selection
#
#
# 	  Explanation.prototype.show = function show(exp, label, div) {
# 	    var svg = div.append('svg').style('width', '100%');
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    var names = ['NOT ' + this.names[label], this.names[label]];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	      names = this.names;
# 	    }
# 	    var plot = new _bar_chart2.default(svg, exp, true, names, colors, true, 10);
# 	    svg.style('height', plot.svg_height + 'px');
# 	  };
# 	  // exp has all ocurrences of words, with start index and weight:
# 	  // exp = [('word', 132, -0.13), ('word3', 111, 1.3)
#
#
# 	  Explanation.prototype.show_raw_text = function show_raw_text(exp, label, raw, div) {
# 	    var opacity = arguments.length > 4 && arguments[4] !== undefined ? arguments[4] : true;
#
# 	    //let colors=['#5F9EA0', this.colors(this.exp['class'])];
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var word_lists = [[], []];
# 	    var max_weight = -1;
# 	    var _iteratorNormalCompletion = true;
# 	    var _didIteratorError = false;
# 	    var _iteratorError = undefined;
#
# 	    try {
# 	      for (var _iterator = exp[Symbol.iterator](), _step; !(_iteratorNormalCompletion = (_step = _iterator.next()).done); _iteratorNormalCompletion = true) {
# 	        var _step$value = _slicedToArray(_step.value, 3),
# 	            word = _step$value[0],
# 	            start = _step$value[1],
# 	            weight = _step$value[2];
#
# 	        if (weight > 0) {
# 	          word_lists[1].push([start, start + word.length, weight]);
# 	        } else {
# 	          word_lists[0].push([start, start + word.length, -weight]);
# 	        }
# 	        max_weight = Math.max(max_weight, Math.abs(weight));
# 	      }
# 	    } catch (err) {
# 	      _didIteratorError = true;
# 	      _iteratorError = err;
# 	    } finally {
# 	      try {
# 	        if (!_iteratorNormalCompletion && _iterator.return) {
# 	          _iterator.return();
# 	        }
# 	      } finally {
# 	        if (_didIteratorError) {
# 	          throw _iteratorError;
# 	        }
# 	      }
# 	    }
#
# 	    if (!opacity) {
# 	      max_weight = 0;
# 	    }
# 	    this.display_raw_text(div, raw, word_lists, colors, max_weight, true);
# 	  };
# 	  // exp is list of (feature_name, value, weight)
#
#
# 	  Explanation.prototype.show_raw_tabular = function show_raw_tabular(exp, label, div) {
# 	    div.classed('lime', true).classed('table_div', true);
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var table = div.append('table');
# 	    var thead = table.append('tr');
# 	    thead.append('td').text('Feature');
# 	    thead.append('td').text('Value');
# 	    thead.style('color', 'black').style('font-size', '20px');
# 	    var _iteratorNormalCompletion2 = true;
# 	    var _didIteratorError2 = false;
# 	    var _iteratorError2 = undefined;
#
# 	    try {
# 	      for (var _iterator2 = exp[Symbol.iterator](), _step2; !(_iteratorNormalCompletion2 = (_step2 = _iterator2.next()).done); _iteratorNormalCompletion2 = true) {
# 	        var _step2$value = _slicedToArray(_step2.value, 3),
# 	            fname = _step2$value[0],
# 	            value = _step2$value[1],
# 	            weight = _s

# %% [markdown]
# ### Next Steps and Recommendations

# %% [markdown]
# Please refer to the associated README file with this project for next steps
